# %%
# tag the test file with spacy, with entity type and entity links
import os, json, pprint, tagme, pickle, spacy
from spacy.pipeline import EntityLinker
path_data = "/data/cm/"
path = "/home/rovera/cm/"

# %%
nlp = spacy.load("de_core_news_lg")

# %%
entity_linker = EntityLinker(nlp.vocab)

optimizer = entity_linker.begin_training(pipeline=nlp.pipeline)
nlp.add_pipe(entity_linker, last=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6928b7364420> in <module>
#       1 entity_linker = EntityLinker(nlp.vocab)
#       2
# ----> 3 optimizer = entity_linker.begin_training(pipeline=nlp.pipeline)
#       4 nlp.add_pipe(entity_linker, last=True)
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.begin_training()
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.require_kb()
#
# ValueError: [E139] Knowledge Base for component 'entity_linker' not initialized. Did you forget to call set_kb()?

# %%
doc = nlp("Angela Merkel hat gestern beim Bundestag in Berlin geredet.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a2c30f8c3af9> in <module>
# ----> 1 doc = nlp("Angela Merkel hat gestern beim Bundestag in Berlin geredet.")
#
# /data/python/env/lib/python3.8/site-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     447             if not hasattr(proc, "__call__"):
#     448                 raise ValueError(Errors.E003.format(component=type(proc), name=name))
# --> 449             doc = proc(doc, **component_cfg.get(name, {}))
#     450             if doc is None:
#     451                 raise ValueError(Errors.E005.format(name=name))
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.__call__()
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.predict()
#
# pipes.pyx in spacy.pipeline.pipes.EntityLinker.require_model()
#
# ...
