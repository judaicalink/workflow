# %%
# compute keyphraseness = D_link_m / D_m
# D_link_m: number of times the mention m appears as an anchor text of a link
# D_m: number of Wikipedia articles that contain m

import os, pprint, sys, time, pickle, json
from bs4 import BeautifulSoup as bs
root = "/data/cm/"
root_data = root+"data/"
