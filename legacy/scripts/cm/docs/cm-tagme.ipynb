# %% [markdown]
# +++
# author = "Marco Rovera"
# authorlink = "http://wiss.iuk.hdm-stuttgart.de/people/marco-rovera"
# date = "2021-01-18T10:37:07+02:00"
# title = "Linking Compact Memory - Resources and References"
# links = ""
# dataslug = "cm-tagme"
# graph = "http://data.judaicalink.org/data/cm-tagme"
# loaded = false
# category = "judaicalink"
# script = ""
#
# [[files]]
# 	url = "http://data.judaicalink.org/dumps/cm-tagme/cm_tagme_resources.ttl.gz"
# 	description = "Judaicalink Resource mentions in Compact Memory"
#
# [[files]]
# 	url = "http://data.judaicalink.org/dumps/cm-tagme/cm_tagme_references.ttl.gz"
# 	description = "Description of each single mention (start, end, text, page, confidence scores)"
#
# +++
#
# References of Judaicalink resources in Compact Memory.
#
# <!--more-->
