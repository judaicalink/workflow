# %%
from SPARQLWrapper import SPARQLWrapper, JSON
from elasticsearch import Elasticsearch
import json, csv, requests, time, pickle
from urllib.parse import unquote
es = Elasticsearch()

# %%
with open('/data/cm/output/linker/cm_entities_tagme.tsv') as csv_file:
    tagme_output = list(csv.reader(csv_file, delimiter='\t', quotechar='"'))

# %%
def wiki2wikidata(title, lang):
    
    params = {
        'action': 'wbgetentities',
        'sites': lang+'wiki',
        'titles': title,
        'languages': lang,
        'format': 'json'
    }
    base = 'https://www.wikidata.org/w/api.php?'
    params_str = "&".join(["{}={}".format(k,v) for k,v in params.items()])
    
    query = base + params_str
    
    res = requests.get(query)
    
    return res

# %%
sparql = SPARQLWrapper("http://localhost:3040/judaicalink/query")
sparql.setQuery("""
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX foaf: <http://xmlns.com/foaf/0.1/>
    SELECT DISTINCT ?label ?same
    WHERE { GRAPH ?g { ?s skos:prefLabel ?label .
                        # ?s owl:sameAs ?same.
                        # ?s a foaf:Person
    
    }}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
jl_persons = {}
hits = 0
counter = 0
for result in results["results"]["bindings"]:
    counter += 1
    label = result["label"]["value"]
    same = result['same']['value']
    if "," in label:
        label = " ".join(map(str.strip, reversed(label.split(","))))
    #persons.append(label)
    if label in jl_persons:
        jl_persons[label].add(same)
    else:
        jl_persons[label] = set([same])

# %%
len(jl_persons)
# Out:
# 45192

# %%
c = 0
for k,v in jl_persons.items():
    for uri in v:
        if 'wikidata' in uri:
            print(k, uri)
            c += 1
    if c > 10:
        break
# Out:
# Philippe Mesnard http://www.wikidata.org/entity/Q46997964
# Reinhard Piechocki http://www.wikidata.org/entity/Q1382611
# William Douglas Morrison http://www.wikidata.org/entity/Q51573121
# Leone Modena http://www.wikidata.org/entity/Q1652176
# Peter Herde http://www.wikidata.org/entity/Q2075646
# Natan Shaḥam http://www.wikidata.org/entity/Q2910365
# Nancy Huston http://www.wikidata.org/entity/Q237684
# Boleslaus V. Wicherkiewicz http://www.wikidata.org/entity/Q9176983
# Marie-Louise Roth http://www.wikidata.org/entity/Q1897168
# Hans Lenk http://www.wikidata.org/entity/Q70521
# Friedhelm Rathjen http://www.wikidata.org/entity/Q1457253

# %%
# get overlap between jl_persons and tagme output
per_overlap = set([])
for match in tagme_output:
    if match[0] in jl_persons:
        per_overlap.add((match[0], match[6].replace(" ", "_")))
print(len(per_overlap))
# Out:
# 3915

# %%
wikidata_enrichment = {}
c = 0
for el in per_overlap:
    res = wiki2wikidata(el[1], 'de').json()
    wikidata_id = list(res['entities'].keys())[0]
    wikidata_url = 'http://www.wikidata.org/entity/'+wikidata_id
    
    wikidata_enrichment[el] = wikidata_url
    c += 1
    if c % 100 == 0:
        print(c, end=" ")
        print(wikidata_url)
    time.sleep(0.5)
# Out:
# 100 http://www.wikidata.org/entity/Q20657936
# 200 http://www.wikidata.org/entity/Q535396
# 300 http://www.wikidata.org/entity/Q1608348
# 400 http://www.wikidata.org/entity/Q1551290
# 500 http://www.wikidata.org/entity/Q84904
# 600 http://www.wikidata.org/entity/Q506760
# 700 http://www.wikidata.org/entity/Q1177029
# 800 http://www.wikidata.org/entity/Q101542
# 900 http://www.wikidata.org/entity/Q1594243
# 1000 http://www.wikidata.org/entity/Q93444
# 1100 http://www.wikidata.org/entity/Q711755
# 1200 http://www.wikidata.org/entity/Q1610507
# 1300 http://www.wikidata.org/entity/Q1330285
# 1400 http://www.wikidata.org/entity/Q15992069
# 1500 http://www.wikidata.org/entity/Q2177746
# 1600 http://www.wikidata.org/entity/Q2799328
# 1700 http://www.wikidata.org/entity/Q22691903
# 1800 http://www.wikidata.org/entity/Q1065635
# 1900 http://www.wikidata.org/entity/Q103140
# 2000 http://www.wikidata.org/entity/Q76998
# 2100 http://www.wikidata.org/entity/Q1293846
# 2200 http://www.wikidata.org/entity/Q30875
# 2300 http://www.wikidata.org/entity/Q205372
# 2400 http://www.wikidata.org/entity/Q2546692
# 2500 http://www.wikidata.org/entity/-1
# 2600 http://www.wikidata.org/entity/Q1039355
# 2700 http://www.wikidata.org/entity/Q2287639
# 2800 http://www.wikidata.org/entity/Q687245
# 2900 http://www.wikidata.org/entity/Q76820
# 3000 http://www.wikidata.org/entity/Q375311
# 3100 http://www.wikidata.org/entity/Q694105
# 3200 http://www.wikidata.org/entity/Q162389
# 3300 http://www.wikidata.org/entity/Q19758007
# 3400 http://www.wikidata.org/entity/Q725605
# 3500 http://www.wikidata.org/entity/Q13650629
# 3600 http://www.wikidata.org/entity/Q1796290
# 3700 http://www.wikidata.org/entity/Q1819750
# 3800 http://www.wikidata.org/entity/Q2284989
# 3900 http://www.wikidata.org/entity/Q360871

# %%
wikidata_enrichment = {k:v for k,v in wikidata_enrichment.items() if not v.endswith('-1')}

# %%
with open('/data/cm/output/linker/wikidata_enrichment.pickle', 'wb') as outfile:
    pickle.dump(wikidata_enrichment, outfile)

# %%
c = 0
for k, v in wikidata_enrichment.items():
    if v.endswith('-1'):
        print(k,v)

# %%
wikidata_pers = {k[0]: v for k,v in wikidata_enrichment.items()}

# %%
overlap = {}
for match in tagme_output:
    if match[0] in jl_persons:
        wiki_url = 'https://de.wikipedia.org/wiki/'+match[6].replace(" ", "_")
        dbpedia_url_de = 'http://de.dbpedia.org/resource/'+match[6].replace(" ", "_")
        dbpedia_url = 'http://dbpedia.org/resource/'+match[6].replace(" ", "_")
        
        wikidata_url = ''
        try:
            wikidata_url = wikidata_pers[match[0]]
        except KeyError:
            pass
        
        
        tagme_urls = set([wiki_url, dbpedia_url_de, dbpedia_url, wikidata_url])
        if wikidata_url != '':
            tagme_urls.add(wikidata_url)
        jl_urls = {unquote(jl_uri) for jl_uri in persons[match[0]]}
        
        common_urls = jl_urls.intersection(tagme_urls)
        
        if common_urls != set([]):
            overlap[match[0]] = common_urls

# %%
print(len(overlap))
# Out:
# 3018

# %%
i = 0
for k,v in overlap.items():
    i += 1
    if i > 550 and i < 650:
        print(k)
        print(v)
        print()
    if i > 650:
        break
# Out:
# Ernst Cohn-Wiener
# {'https://de.wikipedia.org/wiki/Ernst_Cohn-Wiener', 'http://www.wikidata.org/entity/Q113179'}
#
# Albrecht Alt
# {'https://de.wikipedia.org/wiki/Albrecht_Alt', 'http://www.wikidata.org/entity/Q84895', 'http://dbpedia.org/resource/Albrecht_Alt'}
#
# Clemens Brentano
# {'https://de.wikipedia.org/wiki/Clemens_Brentano', 'http://www.wikidata.org/entity/Q57235', 'http://dbpedia.org/resource/Clemens_Brentano'}
#
# Theodor Reik
# {'https://de.wikipedia.org/wiki/Theodor_Reik', 'http://www.wikidata.org/entity/Q78734', 'http://dbpedia.org/resource/Theodor_Reik'}
#
# Charles Baudelaire
# {'http://www.wikidata.org/entity/Q501', 'https://de.wikipedia.org/wiki/Charles_Baudelaire', 'http://dbpedia.org/resource/Charles_Baudelaire'}
#
# Julius Wellhausen
# {'http://www.wikidata.org/entity/Q76897', 'https://de.wikipedia.org/wiki/Julius_Wellhausen', 'http://dbpedia.org/resource/Julius_Wellhausen'}
#
# Sigmund Mowinckel
# {'http://dbpedia.org/resource/Sigmund_Mowinckel', 'https://de.wikipedia.org/wiki/Sigmund_Mowinckel', 'http://www.wikidata.org/entity/Q981139'}
#
# Elia Levita
# {'http://www.wikidata.org/entity/Q66031', 'http://de.dbpedia.org/resource/Elijah_Levita'}
#
# Albert Ehrenstein
# {'http://www.wikidata.org/entity/Q214947', 'http://dbpedia.org/resource/Albert_Ehrenstein', 'https://de.wikipedia.org/wiki/Albert_Ehrenstein', 'http://de.dbpedia.org/resource/Albert_Ehrenstein'}
#
# Hermann Simon
# {'https://de.wikipedia.org/wiki/Hermann_Simon_(Historiker)'}
#
# Kurt Hiller
# {'https://de.wikipedia.org/wiki/Kurt_Hiller', 'http://dbpedia.org/resource/Kurt_Hiller', 'http://www.wikidata.org/entity/Q66458'}
#
# Leo Baerwald
# {'https://de.wikipedia.org/wiki/Leo_Baerwald', 'http://www.wikidata.org/entity/Q18221174'}
#
# Nahum Sokolow
# {'http://www.wikidata.org/entity/Q918966', 'https://de.wikipedia.org/wiki/Nachum_Sokolow', 'http://de.dbpedia.org/resource/Nachum_Sokolow'}
#
# Kurt Blumenfeld
# {'http://dbpedia.org/resource/Kurt_Blumenfeld', 'http://www.wikidata.org/entity/Q214352', 'https://de.wikipedia.org/wiki/Kurt_Blumenfeld'}
#
# Enzo Sereni
# {'https://de.wikipedia.org/wiki/Enzo_Sereni', 'http://www.wikidata.org/entity/Q573864', 'http://dbpedia.org/resource/Enzo_Sereni'}
#
# Pinchas Kohn
# {'https://de.wikipedia.org/wiki/Pinchas_Kohn', 'http://www.wikidata.org/entity/Q7194906'}
#
# Karl Jakob Hirsch
# {'https://de.wikipedia.org/wiki/Karl_Jakob_Hirsch', 'http://www.wikidata.org/entity/Q1731779'}
#
# Salomon Buber
# {'https://de.wikipedia.org/wiki/Salomon_Buber', 'http://www.wikidata.org/entity/Q982067', 'http://dbpedia.org/resource/Salomon_Buber'}
#
# James Bieberkraut
# {'http://www.wikidata.org/entity/Q1638288', 'https://de.wikipedia.org/wiki/James_Bieberkraut'}
#
# Heinrich Loewe
# {'https://de.wikipedia.org/wiki/Heinrich_Loewe', 'http://www.wikidata.org/entity/Q106246'}
#
# Hermann Kesten
# {'https://de.wikipedia.org/wiki/Hermann_Kesten', 'http://de.dbpedia.org/resource/Hermann_Kesten', 'http://dbpedia.org/resource/Hermann_Kesten', 'http://www.wikidata.org/entity/Q65504'}
#
# Arthur Schnitzler
# {'http://dbpedia.org/resource/Arthur_Schnitzler', 'https://de.wikipedia.org/wiki/Arthur_Schnitzler', 'http://www.wikidata.org/entity/Q44331'}
#
# Mohel
# {'http://www.wikidata.org/entity/Q1853585', 'http://de.dbpedia.org/resource/Mohel', 'http://dbpedia.org/resource/Mohel'}
#
# Israel Alter
# {'https://de.wikipedia.org/wiki/Israel_Alter', 'http://www.wikidata.org/entity/Q15668839', 'http://de.dbpedia.org/resource/Israel_Alter', 'http://dbpedia.org/resource/Israel_Alter'}
#
# Fritz Landauer
# {'https://de.wikipedia.org/wiki/Fritz_Landauer_(Architekt)', 'http://www.wikidata.org/entity/Q18222659'}
#
# Walther Tritsch
# {'http://www.wikidata.org/entity/Q2547486', 'https://de.wikipedia.org/wiki/Walther_Tritsch'}
#
# Max Neuburger
# {'http://www.wikidata.org/entity/Q1913127', 'https://de.wikipedia.org/wiki/Max_Neuburger'}
#
# Ludwig Schwerin
# {'https://de.wikipedia.org/wiki/Ludwig_Schwerin', 'http://www.wikidata.org/entity/Q1875003'}
#
# Konrad Heiden
# {'https://de.wikipedia.org/wiki/Konrad_Heiden', 'http://dbpedia.org/resource/Konrad_Heiden', 'http://www.wikidata.org/entity/Q78290'}
#
# Alfred Neumeyer
# {'https://de.wikipedia.org/wiki/Alfred_Neumeyer_(Jurist)', 'http://www.wikidata.org/entity/Q19243787'}
#
# Hans Goslar
# {'http://www.wikidata.org/entity/Q1320392', 'https://de.wikipedia.org/wiki/Hans_Goslar'}
#
# Sali Levi
# {'http://www.wikidata.org/entity/Q20817373', 'https://de.wikipedia.org/wiki/Sali_Levi'}
#
# Bruno Frank
# {'http://www.wikidata.org/entity/Q62133', 'https://de.wikipedia.org/wiki/Bruno_Frank', 'http://dbpedia.org/resource/Bruno_Frank', 'http://de.dbpedia.org/resource/Bruno_Frank'}
#
# Siegfried Behn
# {'https://de.wikipedia.org/wiki/Siegfried_Behn', 'http://www.wikidata.org/entity/Q20752099'}
#
# Giselher Wirsing
# {'http://www.wikidata.org/entity/Q102747', 'https://de.wikipedia.org/wiki/Giselher_Wirsing'}
#
# Heinrich Eduard Jacob
# {'https://de.wikipedia.org/wiki/Heinrich_Eduard_Jacob', 'http://www.wikidata.org/entity/Q66812', 'http://dbpedia.org/resource/Heinrich_Eduard_Jacob'}
#
# Max Hirschberg
# {'https://de.wikipedia.org/wiki/Max_Hirschberg', 'http://dbpedia.org/resource/Max_Hirschberg', 'http://www.wikidata.org/entity/Q74757', 'http://de.dbpedia.org/resource/Max_Hirschberg'}
#
# Jean Richard Bloch
# {'https://de.wikipedia.org/wiki/Jean-Richard_Bloch', 'http://dbpedia.org/resource/Jean-Richard_Bloch', 'http://www.wikidata.org/entity/Q949281'}
#
# Paul Amann
# {'https://de.wikipedia.org/wiki/Paul_Amann', 'http://www.wikidata.org/entity/Q2058694'}
#
# Willy Cohn
# {'https://de.wikipedia.org/wiki/Willy_Cohn', 'http://www.wikidata.org/entity/Q78377'}
#
# Hugo Zuckermann
# {'https://de.wikipedia.org/wiki/Hugo_Zuckermann', 'http://www.wikidata.org/entity/Q88265', 'http://dbpedia.org/resource/Hugo_Zuckermann'}
#
# Alfons Rosenberg
# {'http://dbpedia.org/resource/Alfons_Rosenberg', 'https://de.wikipedia.org/wiki/Alfons_Rosenberg', 'http://www.wikidata.org/entity/Q100715'}
#
# Walter Korn
# {'http://dbpedia.org/resource/Walter_Korn'}
#
# Siegfried Einstein
# {'http://dbpedia.org/resource/Siegfried_Einstein', 'http://www.wikidata.org/entity/Q103998', 'https://de.wikipedia.org/wiki/Siegfried_Einstein', 'http://de.dbpedia.org/resource/Siegfried_Einstein'}
#
# Hai Gaon
# {'https://de.wikipedia.org/wiki/Hai_Gaon', 'http://de.dbpedia.org/resource/Hai_Gaon', 'http://dbpedia.org/resource/Hai_Gaon', 'http://www.wikidata.org/entity/Q982194'}
#
# Etta Federn-Kohlhaas
# {'https://de.wikipedia.org/wiki/Etta_Federn-Kohlhaas', 'http://www.wikidata.org/entity/Q1371711'}
#
# Karl Gutzkow
# {'http://dbpedia.org/resource/Karl_Gutzkow', 'http://www.wikidata.org/entity/Q76755', 'https://de.wikipedia.org/wiki/Karl_Gutzkow'}
#
# Bernhard Walde
# {'http://www.wikidata.org/entity/Q15992069', 'https://de.wikipedia.org/wiki/Bernhard_Walde'}
#
# Hermann Adler
# {'http://www.wikidata.org/entity/Q1610503', 'https://de.wikipedia.org/wiki/Hermann_Adler_(Schriftsteller)'}
#
# James Loeb
# {'https://de.wikipedia.org/wiki/James_Loeb', 'http://dbpedia.org/resource/James_Loeb', 'http://www.wikidata.org/entity/Q506426', 'http://de.dbpedia.org/resource/James_Loeb'}
#
# Martin Salomonski
# {'https://de.wikipedia.org/wiki/Martin_Salomonski', 'http://www.wikidata.org/entity/Q1904893'}
#
# Samuel Holdheim
# {'http://dbpedia.org/resource/Samuel_Holdheim', 'http://www.wikidata.org/entity/Q63482', 'https://de.wikipedia.org/wiki/Samuel_Holdheim'}
#
# Theodor Fontane
# {'http://www.wikidata.org/entity/Q76632', 'http://dbpedia.org/resource/Theodor_Fontane', 'https://de.wikipedia.org/wiki/Theodor_Fontane'}
#
# Emil Lehmann
# {'https://de.wikipedia.org/wiki/Emil_Lehmann_(Politiker)', 'http://www.wikidata.org/entity/Q1336445'}
#
# Siegfried Moses
# {'https://de.wikipedia.org/wiki/Siegfried_Moses_(Jurist)', 'http://www.wikidata.org/entity/Q2283626'}
#
# Johannes Hehn
# {'http://www.wikidata.org/entity/Q23562017', 'https://de.wikipedia.org/wiki/Johannes_Hehn'}
#
# Jacob Segall
# {'http://www.wikidata.org/entity/Q1677315', 'https://de.wikipedia.org/wiki/Jacob_Segall'}
#
# Leonhard Frank
# {'http://www.wikidata.org/entity/Q77069', 'http://dbpedia.org/resource/Leonhard_Frank', 'https://de.wikipedia.org/wiki/Leonhard_Frank'}
#
# Hugo Gold
# {'http://www.wikidata.org/entity/Q1563496', 'https://de.wikipedia.org/wiki/Hugo_Gold'}
#
# Chajim Bloch
# {'https://de.wikipedia.org/wiki/Chajim_Bloch', 'http://www.wikidata.org/entity/Q1059214'}
#
# Siegfried Rosenfeld
# {'https://de.wikipedia.org/wiki/Siegfried_Rosenfeld', 'http://www.wikidata.org/entity/Q2283706'}
#
# Romano Guardini
# {'https://de.wikipedia.org/wiki/Romano_Guardini', 'http://www.wikidata.org/entity/Q44872', 'http://dbpedia.org/resource/Romano_Guardini'}
#
# Samuel Landauer
# {'http://www.wikidata.org/entity/Q7411966', 'https://de.wikipedia.org/wiki/Samuel_Landauer'}
#
# Jacques Offenbach
# {'http://www.wikidata.org/entity/Q41555', 'https://de.wikipedia.org/wiki/Jacques_Offenbach', 'http://dbpedia.org/resource/Jacques_Offenbach'}
#
# Gotthold Ephraim Lessing
# {'http://dbpedia.org/resource/Gotthold_Ephraim_Lessing', 'http://www.wikidata.org/entity/Q34628', 'https://de.wikipedia.org/wiki/Gotthold_Ephraim_Lessing'}
#
# Recha Freier
# {'https://de.wikipedia.org/wiki/Recha_Freier', 'http://www.wikidata.org/entity/Q96508', 'http://dbpedia.org/resource/Recha_Freier'}
#
# Irma Stern
# {'http://de.dbpedia.org/resource/Irma_Stern', 'http://www.wikidata.org/entity/Q281203', 'http://dbpedia.org/resource/Irma_Stern', 'https://de.wikipedia.org/wiki/Irma_Stern'}
#
# Magnus Weinberg
# {'http://www.wikidata.org/entity/Q22694578', 'https://de.wikipedia.org/wiki/Magnus_Weinberg'}
#
# Anton Chroust
# {'http://www.wikidata.org/entity/Q15139288', 'https://de.wikipedia.org/wiki/Anton_Chroust'}
#
# Ezechiel Zivier
# {'https://de.wikipedia.org/wiki/Ezechiel_Zivier', 'http://www.wikidata.org/entity/Q1385970'}
#
# Erich Brandenburg
# {'https://de.wikipedia.org/wiki/Erich_Brandenburg', 'http://www.wikidata.org/entity/Q74795', 'http://dbpedia.org/resource/Erich_Brandenburg'}
#
# Fritz Wisten
# {'https://de.wikipedia.org/wiki/Fritz_Wisten', 'http://www.wikidata.org/entity/Q1468949'}
#
# Georg Flatow
# {'https://de.wikipedia.org/wiki/Georg_Flatow', 'http://www.wikidata.org/entity/Q18333367'}
#
# Heinrich Fraenkel
# {'http://dbpedia.org/resource/Heinrich_Fraenkel', 'https://de.wikipedia.org/wiki/Heinrich_Fraenkel', 'http://www.wikidata.org/entity/Q110733'}
#
# Alexander Granach
# {'http://www.wikidata.org/entity/Q78817', 'https://de.wikipedia.org/wiki/Alexander_Granach', 'http://dbpedia.org/resource/Alexander_Granach'}
#
# Hans Windisch
# {'https://de.wikipedia.org/wiki/Hans_Windisch_(Theologe)'}
#
# Wilhelm Raabe
# {'https://de.wikipedia.org/wiki/Wilhelm_Raabe', 'http://dbpedia.org/resource/Wilhelm_Raabe', 'http://www.wikidata.org/entity/Q60647'}
#
# Uriel Birnbaum
# {'https://de.wikipedia.org/wiki/Uriel_Birnbaum', 'http://www.wikidata.org/entity/Q216347', 'http://dbpedia.org/resource/Uriel_Birnbaum'}
#
# Otto Weber
# {'http://www.wikidata.org/entity/Q1530496', 'https://de.wikipedia.org/wiki/Otto_Weber_(Theologe)'}
#
# Fritz Stern
# {'https://de.wikipedia.org/wiki/Fritz_Stern', 'http://de.dbpedia.org/resource/Fritz_Stern', 'http://dbpedia.org/resource/Fritz_Stern', 'http://www.wikidata.org/entity/Q66375'}
#
# Max Cohen
# {'https://de.wikipedia.org/wiki/Max_Cohen_(Journalist)', 'http://www.wikidata.org/entity/Q118129'}
#
# Max Diamant
# {'http://www.wikidata.org/entity/Q1912395', 'https://de.wikipedia.org/wiki/Max_Diamant'}
#
# Wolfgang Capito
# {'http://www.wikidata.org/entity/Q1368362', 'http://dbpedia.org/resource/Wolfgang_Capito', 'https://de.wikipedia.org/wiki/Wolfgang_Capito'}
#
# Aron Freimann
# {'http://www.wikidata.org/entity/Q75342', 'http://dbpedia.org/resource/Aron_Freimann', 'http://de.dbpedia.org/resource/Aron_Freimann', 'https://de.wikipedia.org/wiki/Aron_Freimann'}
#
# Bernhard Brilling
# {'http://www.wikidata.org/entity/Q824812', 'https://de.wikipedia.org/wiki/Bernhard_Brilling'}
#
# Fritz Pinkuss
# {'https://de.wikipedia.org/wiki/Fritz_Pinkuss', 'http://www.wikidata.org/entity/Q1467777'}
#
# Hans Kaufmann
# {'http://www.wikidata.org/entity/Q1580700'}
#
# George S. Kaufman
# {'https://de.wikipedia.org/wiki/George_Simon_Kaufman', 'http://www.wikidata.org/entity/Q163662'}
#
# Bertha von Suttner
# {'http://dbpedia.org/resource/Bertha_von_Suttner', 'http://www.wikidata.org/entity/Q18456', 'https://de.wikipedia.org/wiki/Bertha_von_Suttner'}
#
# Dietrich von Hildebrand
# {'https://de.wikipedia.org/wiki/Dietrich_von_Hildebrand', 'http://www.wikidata.org/entity/Q14678', 'http://dbpedia.org/resource/Dietrich_von_Hildebrand'}
#
# Lovis Corinth
# {'http://www.wikidata.org/entity/Q157610', 'https://de.wikipedia.org/wiki/Lovis_Corinth', 'http://dbpedia.org/resource/Lovis_Corinth'}
#
# Wilhelm Walther
# {'https://de.wikipedia.org/wiki/Wilhelm_Walther_(Theologe)', 'http://www.wikidata.org/entity/Q2575563'}
#
# Carl Zuckmayer
# {'https://de.wikipedia.org/wiki/Carl_Zuckmayer', 'http://dbpedia.org/resource/Carl_Zuckmayer', 'http://www.wikidata.org/entity/Q76820'}
#
# Karl Neumeyer
# {'https://de.wikipedia.org/wiki/Karl_Neumeyer', 'http://www.wikidata.org/entity/Q15444706'}
#
# Gottfried Feder
# {'http://www.wikidata.org/entity/Q60126', 'http://dbpedia.org/resource/Gottfried_Feder', 'https://de.wikipedia.org/wiki/Gottfried_Feder'}
#
# Michael von Faulhaber
# {'https://de.wikipedia.org/wiki/Michael_von_Faulhaber', 'http://www.wikidata.org/entity/Q45160', 'http://dbpedia.org/resource/Michael_von_Faulhaber'}
#
# Isidor Singer
# {'http://www.wikidata.org/entity/Q1315842', 'https://de.wikipedia.org/wiki/Isidor_Singer_(Journalist)'}
#
# Sigismund Stern
# {'https://de.wikipedia.org/wiki/Sigismund_Stern', 'http://www.wikidata.org/entity/Q18418723'}
#
# Eugen Landau
# {'http://www.wikidata.org/entity/Q1372709', 'https://de.wikipedia.org/wiki/Eugen_Landau'}

# %%
mentions_overlap = 0
for mention in tagme_output:
    if mention[0] in overlap:
        #print(jl_person)
        mentions_overlap += 1
print("Found {} JL person mentions in CM.".format(mentions_overlap))
# Out:
# Found 282613 JL persons in CM.
