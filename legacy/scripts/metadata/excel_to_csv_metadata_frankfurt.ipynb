# %%
# convert the excel compact memory metadata file to tsv for further use
import os, csv
import pandas as pd
root = '/data/cm/'

# %%
df = pd.read_excel(root+'data/metadata/CM_Seiten_Metadaten.xlsx')  # sheetname is optional
df.to_csv(root+'data/metadata/CM_Seiten_Metadaten.csv', sep='\t', index=False)  # index=False prevents pandas to write row ind
