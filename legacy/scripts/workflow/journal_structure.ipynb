# %%
import os, pprint
path = "/data/cm/"

# %%
path_struct = list(os.walk(path+"xml/2580773/"))

# %%
file_count = 0
i = 0

path_struct = os.walk(path+"xml/"+"2446951")
for dirpath, dirs, files in path_struct:
    if files != []:
        print(dirpath)
        print(dirs)
        print(files)
        print()
        file_count += len(files)
        i += 1
        if i > 10:
            break

#print(file_count, "files to be processed in CM")
# Out:
# /data/cm/xml/2446951/2450547/2450549
# []
# ['75644_2533177.xml', '75645_2533178.xml', '75654_2533187.xml', '75642_2533175.xml', '75639_2533172.xml', '75647_2533180.xml', '75640_2533173.xml', '75641_2533174.xml', '75646_2533179.xml', '75655_2533188.xml', '75638_2533171.xml', '75651_2533184.xml', '75653_2533186.xml', '75643_2533176.xml', '75649_2533182.xml', '75652_2533185.xml', '75650_2533183.xml', '75648_2533181.xml']
#
# /data/cm/xml/2446951/2450547/2450589
# []
# ['76413_2533987.xml', '76416_2533990.xml', '76402_2533976.xml', '76415_2533989.xml', '76406_2533980.xml', '76393_2533967.xml', '76400_2533974.xml', '76408_2533982.xml', '76398_2533972.xml', '76395_2533969.xml', '76409_2533983.xml', '76410_2533984.xml', '76394_2533968.xml', '76405_2533979.xml', '76414_2533988.xml', '76411_2533985.xml', '76412_2533986.xml', '76404_2533978.xml', '76407_2533981.xml', '76399_2533973.xml', '76397_2533971.xml', '76401_2533975.xml', '76403_2533977.xml', '76396_2533970.xml']
#
# ...
