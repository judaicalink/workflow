# %%
import os, json, pickle, pprint

# %%
class Cooccurrence():
    
    def __init__(self):
        self.raw_data = None
        self.ents_by_page = None
        self.abs_cooc = None
        self.pmi_cooc = None
    
    def get_stats(self):
        if self.ents_by_page == None:
            print("Please first group entities by page.")
        else:
            pages = len(self.ents_by_page)
            mentions_n = sum(len(v) for v in self.ents_by_page.values())
            avg = mentions_n/len(self.ents_by_page)
            print("Found {} mentions in {} pages ({} mentions/page).".format(mentions_n, pages, avg))
    
    def load_input_data(self, datapath):
        print("Loading input...", end=" ")
        self.raw_data = pickle.load(open(datapath, 'rb'))
        print("Done!")
    
    def group_by_page(self, verbose=True):
        if self.raw_data == None:
            print("Maybe you forgot to load the data?!")
        else:
            self.ents_by_page = {}
            for mention in self.raw_data:
                if mention['page_id'] not in self.ents_by_page:
                    self.ents_by_page[mention['page_id']] = set([])
                self.ents_by_page[mention['page_id']].add((mention['resource'], int(mention['start']), int(mention['end'])))
            if verbose:
                self.get_stats()
            
    def get_abs_cooccurrence(self, offset, verbose=True):
        if self.ents_by_page == None:
            print("Please first group entities by page.")
        else:
            self.abs_cooc = {}
            for pool in self.ents_by_page.values():
                for entity in pool:
                    if entity[0] not in self.abs_cooc:
                        self.abs_cooc[entity[0]] = {}
                    for cooccurrent in pool:
                        if cooccurrent[0] != entity[0] and abs(cooccurrent[1]-entity[1]) < offset:
                            if cooccurrent[0] not in self.abs_cooc[entity[0]]:
                                self.abs_cooc[entity[0]][cooccurrent[0]] = 0
                            self.abs_cooc[entity[0]][cooccurrent[0]] += 1
            if verbose:
                print("Computed absolute entity cooccurrence.")
                
    def get_top_10_cooccurrents(self, resource_uri):
        if resource_uri not in self.abs_cooc:
            print("This entity is not in the dataset :(")
        else:
            sorted_cooccurrents = sorted([(k,v) for k,v in self.abs_cooc[resource_uri].items()], key=lambda x:x[1], reverse=True)
            pprint.pprint(sorted_cooccurrents)
            #for i in range(10):
            #    if i <= len(sorted_cooccurrents):
            #        print(sorted_cooccurrents[i])

# %%
co = Cooccurrence()
co.load_input_data('cm_tagme_resource_reference_data_05_03.pickle')
# Out:
# Loading input... Done!

# %%
co.group_by_page()
# Out:
# Found 1528126 mentions in 465854 pages (3.280268066819218 mentions/page).

# %%
co.get_abs_cooccurrence(400)
# Out:
# Computed absolute entity cooccurrence.

# %%
co.get_top_10_cooccurrents('http://data.judaicalink.org/data/dbpedia/Arnold_Schönberg')
# Out:
# [('http://data.judaicalink.org/data/dbpedia/Gustav_Mahler', 19),
#  ('http://data.judaicalink.org/data/dbpedia/Darius_Milhaud', 10),
#  ('http://data.judaicalink.org/data/dbpedia/Israel', 6),
#  ('http://data.judaicalink.org/data/dbpedia/Max_Brod', 4),
#  ('http://data.judaicalink.org/data/dbpedia/Alban_Berg', 4),
#  ('http://data.judaicalink.org/data/dbpedia/Breslau', 3),
#  ('http://data.judaicalink.org/data/dbpedia/Sigmund_Freud', 3),
#  ('http://data.judaicalink.org/data/dbpedia/Buenos_Aires', 3),
#  ('http://data.judaicalink.org/data/dbpedia/Bertha_Badt-Strauss', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Ismar_Elbogen', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Karl_Wolfskehl', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Heinrich_Berl', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Budapest', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Tunis', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Los_Angeles', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Henri_Bergson', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Emil_Ludwig', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Karl_Kraus', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Max_Reinhardt', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Igor_Strawinsky', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Molière', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Stefan_Zweig', 2),
#  ('http://data.judaicalink.org/data/dbpedia/Rudolf_Levy', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Jakob_Elias_Poritzky', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Franz_Rosenzweig', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Georg_Philipp_Telemann', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Emanuel_Feuermann', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Franz_Landsberger', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Leo_Hirsch', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Leopold_von_Ranke', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Plauen', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Balak_(Person)', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Ernst_Toch', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Theodor_Herzl', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Edmund_Eysler', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Juliusz_Wolfsohn', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Philadelphia', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Melbourne', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Leo_Motzkin', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Brooklyn', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Vilnius', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Hermann_Levy', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Max_Dienemann', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Alfred_Auerbach', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Peter_Gradenwitz', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Selma_Lagerlöf', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Hugo_Zuckermann', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Friedrich_Gundolf', 1),
#  ('http://data.judaicalink.org/data/dbpedia/David_Reuveni', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Mark_Twain', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Berlin', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Richard_Strauss', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Thomas_Mann', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Jens_Peter_Jacobsen', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Jacques_Offenbach', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Felix_Mendelssohn_Bartholdy', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Marc_Chagall', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Ernst_Cassirer', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Paul_Amann', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Arno_Nadel', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Robert_Weltsch', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Franz_Oppenheimer', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Camille_Pissarro', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Otto_Abeles', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Franz_Schubert', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Max_Mell', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Franz_Werfel', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Max_Kowalski', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Franz_Liszt', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Arthur_Schnitzler', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Peter_Altenberg', 1),
#  ('http://data.judaicalink.org/data/dbpedia/Marie_Pappenheim', 1)]
