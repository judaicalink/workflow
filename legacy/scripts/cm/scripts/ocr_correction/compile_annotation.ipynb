# %%
import os, pprint, csv, json
import pandas as pd
path_data = "/data/cm/"
path = "/home/rovera/cm/"

# %%
def compile_annotation(excel_file, csv_file):
    df = pd.read_excel(excel_file)  # sheetname is optional
    df.to_csv(csv_file, sep='\t', index=False)  # index=False prevents pandas to write row ind

# %%
excel_file = path_data+"data/ocr_correction/ongoing/annotation_set_2.xlsx"
csv_file = path_data+"data/ocr_correction/complete/annotation_set_2.csv"
compile_annotation(excel_file, csv_file)
