# %% [markdown]
# +++
# author = "Marco Rovera"
# authorlink = "http://wiss.iuk.hdm-stuttgart.de/people/marco-rovera"
# date = "2021-01-18T10:37:07+02:00"
# title = "Linking Compact Memory - Pages"
# links = ""
# dataslug = "compact-memory"
# graph = "http://data.judaicalink.org/data/compact-memory"
# loaded = false
# category = "judaicalink"
# script = ""
#
# [[files]]
# 	url = "http://data.judaicalink.org/dumps/cm-tagme/cm_pages.ttl.gz"
# 	description = "Page metadata for Compact Memory (where entity references have been found)."
#
#
# +++
#
# .
#
# <!--more-->
