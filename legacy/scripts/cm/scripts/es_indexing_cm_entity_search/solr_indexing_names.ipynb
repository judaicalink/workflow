# %%
# Create an ES index for entity names. This index is used in the search page of the Compact Memory entity search
# https://labs.judaicalink.org/cm_e_search/
# as a backend for the autocomplete functionality

import os, json, pprint, time, pysolr, requests

# %%
root_path = "/data/scripts/cm/scripts/"
SOLR_URL = "http://localhost:8983/solr"
CORE_NAME = "cm_entity_names"
CONFIG_SET = "_default"

# %% [markdown]
# Import the files for the uri's

# %%
uri_to_name = json.load(open(root_path + 'cooccurrence/output/uri_to_name.json', 'r', encoding="utf-8"))
name_to_uri = json.load(open(root_path + 'cooccurrence/output/name_to_uri.json', 'r', encoding="utf-8"))

# %%
data = []
i = 0
for name, uri in name_to_uri.items():
    
    header = {'_id': str(i), '_index': 'cm_entity_names'}
    body = {'name': name, 'uri': uri}
    
    
    data.append(json.dumps({"index": header}, ensure_ascii=False))
    data.append(json.dumps(body, ensure_ascii=False))
    
    i += 1

# %%
print(data[0])
# Out:
# {"index": {"_id": "0", "_index": "cm_entity_names"}}

# %%
mappings = {
    'properties': {
        'name': {'type': 'text'},
        'uri': {'type': 'text'}
    }
}

# %% [markdown]
# Create the SOLR Core

# %%
# --- Configuration ---

def solr_core_exists(solr_url: str, core_name: str) -> bool:
    """
    Check if a given Solr core exists using the Core Admin STATUS action.
    """
    status_url = f"{solr_url}/admin/cores"
    params = {
        "action": "STATUS",
        "core": core_name,
        "wt": "json",
    }

    response = requests.get(status_url, params=params)
    response.raise_for_status()
    data = response.json()

    # If the core exists, it should appear in the "status" dict with some content
    status = data.get("status", {})
    return core_name in status and bool(status[core_name])


def solr_delete_core(solr_url: str, core_name: str) -> None:
    """
    Delete (unload) a Solr core and remove its index, data and instance directory.
    """
    unload_url = f"{solr_url}/admin/cores"
    params = {
        "action": "UNLOAD",
        "core": core_name,
        "deleteIndex": "true",
        "deleteDataDir": "true",
        "deleteInstanceDir": "true",
        "wt": "json",
    }

    print(f"Unloading and deleting core '{core_name}' …")
    response = requests.get(unload_url, params=params)
    response.raise_for_status()
    print(f"Core '{core_name}' successfully unloaded and deleted.")
    print(response.json())


def solr_create_core(solr_url: str, core_name: str, config_set: str) -> None:
    """
    Create a Solr core using a given configSet.
    """
    create_url = f"{solr_url}/admin/cores"
    params = {
        "action": "CREATE",
        "name": core_name,
        "configSet": config_set,
        "wt": "json",
    }

    print(f"Creating core '{core_name}' with configSet '{config_set}' …")
    response = requests.get(create_url, params=params)
    response.raise_for_status()
    print(f"Core '{core_name}' successfully created.")
    print(response.json())


def recreate_solr_core(solr_url: str, core_name: str, config_set: str) -> None:
    """
    Check if the core exists, delete it if necessary, and create it again.
    """
    try:
        if solr_core_exists(solr_url, core_name):
            print(f"Core '{core_name}' already exists.")
            solr_delete_core(solr_url, core_name)
            # Small delay to give Solr time to clean up
            time.sleep(2)
        else:
            print(f"Core '{core_name}' does not exist yet.")

        solr_create_core(solr_url, core_name, config_set)
    except requests.RequestException as e:
        print("Error while communicating with Solr:")
        print(e)


# --- Run ---
recreate_solr_core(SOLR_URL, CORE_NAME, CONFIG_SET)
# Out:
# Core 'cm_entity_names' already exists.
# Unloading and deleting core 'cm_entity_names' …
# Core 'cm_entity_names' successfully unloaded and deleted.
# {'responseHeader': {'status': 0, 'QTime': 127}}
# Creating core 'cm_entity_names' with configSet '_default' …
# Core 'cm_entity_names' successfully created.
# {'responseHeader': {'status': 0, 'QTime': 177}, 'core': 'cm_entity_names'}

# %%
solr = pysolr.Solr(f"{SOLR_URL}/{CORE_NAME}", always_commit=False, timeout=10)

# %% [markdown]
# Bulk upload the data into the SOLR Core

# %%
docs = []
current_id = None

for line in data:
    obj = json.loads(line)  # String -> Dict

    if "index" in obj:
        current_id = obj["index"]["_id"]
    else:
        doc = {
            "id": current_id,
            "name": obj["name"],
            "uri": obj["uri"],
        }
        docs.append(doc)

len(docs), docs[:5]
# Out:
# (6054,
#  [{'id': '0',
#    'name': 'Franz Mehring',
#    'uri': 'http://data.judaicalink.org/data/dbpedia/Franz_Mehring'},
#   {'id': '1',
#    'name': 'Hans Blüher',
#    'uri': 'http://data.judaicalink.org/data/dbpedia/Hans_Blüher'},
#   {'id': '2',
#    'name': 'Wilhelm Börner (Philosoph)',
#    'uri': 'http://data.judaicalink.org/data/dbpedia/Wilhelm_Börner_(Philosoph)'},
#   {'id': '3',
#    'name': 'Heinrich Mann',
#    'uri': 'http://data.judaicalink.org/data/dbpedia/Heinrich_Mann'},
#   {'id': '4',
#    'name': 'Aschersleben',
#    'uri': 'http://data.judaicalink.org/data/dbpedia/Aschersleben'}])

# %%
solr = pysolr.Solr(f"{SOLR_URL}/{CORE_NAME}", timeout=200)

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i+n]

# send in chunks
for chunk in chunks(docs, 1000):
    solr.add(chunk, commit=False)

# commit at the end
solr.commit()
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<response>\n\n<lst name="responseHeader">\n  <int name="status">0</int>\n  <int name="QTime">199</int>\n</lst>\n</response>\n'

# %% [markdown]
# Test query

# %%
solr = pysolr.Solr(f"{SOLR_URL}/{CORE_NAME}", always_commit=False, timeout=10)
start = time.time()
res = solr.search('*:*', index=CORE_NAME, rows=10000)
end = time.time()
print("Search took", round(end-start, 2))
# Out:
# Search took 0.23

# %%
print(res.hits)
# Out:
# 6054

# %%
for doc in res:
    print('Name:', doc['name'])
    print('URI:', doc['uri'])
    print()
# Out:
# Name: ['Franz Mehring']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Mehring']
#
# Name: ['Hans Blüher']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hans_Blüher']
#
# Name: ['Wilhelm Börner (Philosoph)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Börner_(Philosoph)']
#
# Name: ['Heinrich Mann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Heinrich_Mann']
#
# Name: ['Aschersleben']
# URI: ['http://data.judaicalink.org/data/dbpedia/Aschersleben']
#
# Name: ['Dresden']
# URI: ['http://data.judaicalink.org/data/dbpedia/Dresden']
#
# Name: ['Głogów']
# URI: ['http://data.judaicalink.org/data/dbpedia/Głogów']
#
# Name: ['Jelenia Góra']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jelenia_Góra']
#
# Name: ['Wladimir Iljitsch Lenin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wladimir_Iljitsch_Lenin']
#
# Name: ['Pjotr Alexejewitsch Kropotkin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Pjotr_Alexejewitsch_Kropotkin']
#
# Name: ['Rheine']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rheine']
#
# Name: ['Chemnitz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Chemnitz']
#
# Name: ['Breslau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Breslau']
#
# Name: ['Rudolf Leonhard']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rudolf_Leonhard']
#
# Name: ['Maurycy Allerhand']
# URI: ['http://data.judaicalink.org/data/dbpedia/Maurycy_Allerhand']
#
# Name: ['Karl Lieblich']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Lieblich']
#
# Name: ['Selb']
# URI: ['http://data.judaicalink.org/data/dbpedia/Selb']
#
# Name: ['Israel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Israel']
#
# Name: ['Brodnica']
# URI: ['http://data.judaicalink.org/data/dbpedia/Brodnica']
#
# Name: ['Salomo']
# URI: ['http://data.judaicalink.org/data/dbpedia/Salomo']
#
# Name: ['Pécs']
# URI: ['http://data.judaicalink.org/data/dbpedia/Pécs']
#
# Name: ['Zacharias Frankel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Zacharias_Frankel']
#
# Name: ['Dolný Kubín']
# URI: ['http://data.judaicalink.org/data/dbpedia/Dolný_Kubín']
#
# Name: ['Alzey']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alzey']
#
# Name: ['Magdeburg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Magdeburg']
#
# Name: ['Haman']
# URI: ['http://data.judaicalink.org/data/dbpedia/Haman']
#
# Name: ['Budapest']
# URI: ['http://data.judaicalink.org/data/dbpedia/Budapest']
#
# Name: ['Jesaja']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jesaja']
#
# Name: ['Jeremia']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jeremia']
#
# Name: ['Agen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Agen']
#
# Name: ['Legnica']
# URI: ['http://data.judaicalink.org/data/dbpedia/Legnica']
#
# Name: ['Rabbi Akiba']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rabbi_Akiba']
#
# Name: ['Żory']
# URI: ['http://data.judaicalink.org/data/dbpedia/Żory']
#
# Name: ['Rawicz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rawicz']
#
# Name: ['Chasan (Kantor)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Chasan_(Kantor)']
#
# Name: ['Raschi']
# URI: ['http://data.judaicalink.org/data/dbpedia/Raschi']
#
# Name: ['Wilhelm I. (Deutsches Reich)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_I._(Deutsches_Reich)']
#
# Name: ['Wilhelm II. (Deutsches Reich)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_II._(Deutsches_Reich)']
#
# Name: ['Schalkau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schalkau']
#
# Name: ['Tiberias']
# URI: ['http://data.judaicalink.org/data/dbpedia/Tiberias']
#
# Name: ['Schammai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schammai']
#
# Name: ['Joseph Perles']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joseph_Perles']
#
# Name: ['Leopold Löw']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leopold_Löw']
#
# Name: ['Bratislava']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bratislava']
#
# Name: ['Laupheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Laupheim']
#
# Name: ['Samuel ben Chofni']
# URI: ['http://data.judaicalink.org/data/dbpedia/Samuel_ben_Chofni']
#
# Name: ['Stadtlengsfeld']
# URI: ['http://data.judaicalink.org/data/dbpedia/Stadtlengsfeld']
#
# Name: ['Hirsch Aub']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hirsch_Aub']
#
# Name: ['Wetzlar']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wetzlar']
#
# Name: ['Głubczyce']
# URI: ['http://data.judaicalink.org/data/dbpedia/Głubczyce']
#
# Name: ['Maimonides']
# URI: ['http://data.judaicalink.org/data/dbpedia/Maimonides']
#
# Name: ['Gera']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gera']
#
# Name: ['Friedrich Wilhelm III. (Preußen)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Wilhelm_III._(Preußen)']
#
# Name: ['Zadoc Kahn']
# URI: ['http://data.judaicalink.org/data/dbpedia/Zadoc_Kahn']
#
# Name: ['Irschen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Irschen']
#
# Name: ['Ezechiel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ezechiel']
#
# Name: ['Jakob Chagis']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Chagis']
#
# Name: ['Adolf Schwarz (Rabbiner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Adolf_Schwarz_(Rabbiner)']
#
# Name: ['Levi ben Gershon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Levi_ben_Gershon']
#
# Name: ['Ivančice']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ivančice']
#
# Name: ['Alexander Kohut']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alexander_Kohut']
#
# Name: ['Kaleb']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kaleb']
#
# Name: ['Timișoara']
# URI: ['http://data.judaicalink.org/data/dbpedia/Timișoara']
#
# Name: ['Gotthard Deutsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gotthard_Deutsch']
#
# Name: ['Balak (Person)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Balak_(Person)']
#
# Name: ['Bytom']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bytom']
#
# Name: ['Eisenach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eisenach']
#
# Name: ['Remiremont']
# URI: ['http://data.judaicalink.org/data/dbpedia/Remiremont']
#
# Name: ['Żnin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Żnin']
#
# Name: ['Joab']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joab']
#
# Name: ['Mordechai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mordechai']
#
# Name: ['Moses Samuel Zuckermandel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moses_Samuel_Zuckermandel']
#
# Name: ['Michael Sachs (Rabbiner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Michael_Sachs_(Rabbiner)']
#
# Name: ['Franz Joseph I.']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Joseph_I.']
#
# Name: ['Jacob Hamburger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jacob_Hamburger']
#
# Name: ['Philipp Bloch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Philipp_Bloch']
#
# Name: ['Jochanan bar Nappacha']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jochanan_bar_Nappacha']
#
# Name: ['Jochanan ben Sakkai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jochanan_ben_Sakkai']
#
# Name: ['Elija']
# URI: ['http://data.judaicalink.org/data/dbpedia/Elija']
#
# Name: ['Güstrow']
# URI: ['http://data.judaicalink.org/data/dbpedia/Güstrow']
#
# Name: ['Ben Soma']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ben_Soma']
#
# Name: ['Ludwig Strauss']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Strauss']
#
# Name: ['Maurice de Hirsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Maurice_de_Hirsch']
#
# Name: ['Halberstadt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Halberstadt']
#
# Name: ['Samuel Hirsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Samuel_Hirsch']
#
# Name: ['David Hoffmann']
# URI: ['http://data.judaicalink.org/data/dbpedia/David_Hoffmann']
#
# Name: ['Samson Raphael Hirsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Samson_Raphael_Hirsch']
#
# Name: ['Mendel Hirsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mendel_Hirsch']
#
# Name: ['Alexander Jannäus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alexander_Jannäus']
#
# Name: ['Napoleon III.']
# URI: ['http://data.judaicalink.org/data/dbpedia/Napoleon_III.']
#
# Name: ['Texas']
# URI: ['http://data.judaicalink.org/data/dbpedia/Texas']
#
# Name: ['Erasmus von Rotterdam']
# URI: ['http://data.judaicalink.org/data/dbpedia/Erasmus_von_Rotterdam']
#
# Name: ['Voltaire']
# URI: ['http://data.judaicalink.org/data/dbpedia/Voltaire']
#
# Name: ['Jakob Ettlinger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Ettlinger']
#
# Name: ['Glückstadt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Glückstadt']
#
# Name: ['Emil Carlebach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Emil_Carlebach']
#
# Name: ['Flavius Josephus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Flavius_Josephus']
#
# Name: ['Ijob']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ijob']
#
# Name: ['Julius Stern (Musiker)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Julius_Stern_(Musiker)']
#
# Name: ['Lyon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lyon']
#
# Name: ['Heinrich Schwarzschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Heinrich_Schwarzschild']
#
# Name: ['Molière']
# URI: ['http://data.judaicalink.org/data/dbpedia/Molière']
#
# Name: ['Torquato Tasso']
# URI: ['http://data.judaicalink.org/data/dbpedia/Torquato_Tasso']
#
# Name: ['Emanuel Carlebach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Emanuel_Carlebach']
#
# Name: ['Aristoteles']
# URI: ['http://data.judaicalink.org/data/dbpedia/Aristoteles']
#
# Name: ['Alexandria']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alexandria']
#
# Name: ['Moritz Daniel Oppenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moritz_Daniel_Oppenheim']
#
# Name: ['Salomon Kohn (Rabbiner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Salomon_Kohn_(Rabbiner)']
#
# Name: ['Louise von Rothschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Louise_von_Rothschild']
#
# Name: ['Fulda']
# URI: ['http://data.judaicalink.org/data/dbpedia/Fulda']
#
# Name: ['Leopold Marx']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leopold_Marx']
#
# Name: ['Jakob Joseph Frank']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Joseph_Frank']
#
# Name: ['Avignon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Avignon']
#
# Name: ['Vilnius']
# URI: ['http://data.judaicalink.org/data/dbpedia/Vilnius']
#
# Name: ['Riga']
# URI: ['http://data.judaicalink.org/data/dbpedia/Riga']
#
# Name: ['Wilhelm Carl von Rothschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Carl_von_Rothschild']
#
# Name: ['Samuel ben Meir']
# URI: ['http://data.judaicalink.org/data/dbpedia/Samuel_ben_Meir']
#
# Name: ['Hanau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hanau']
#
# Name: ['Daugavpils']
# URI: ['http://data.judaicalink.org/data/dbpedia/Daugavpils']
#
# Name: ['Eberswalde']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eberswalde']
#
# Name: ['Jacob Grimm']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jacob_Grimm']
#
# Name: ['Wolgast']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wolgast']
#
# Name: ['Emden']
# URI: ['http://data.judaicalink.org/data/dbpedia/Emden']
#
# Name: ['Carl Ritter']
# URI: ['http://data.judaicalink.org/data/dbpedia/Carl_Ritter']
#
# Name: ['Gelnhausen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gelnhausen']
#
# Name: ['Bochnia']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bochnia']
#
# Name: ['Kurt Stern (Schriftsteller)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kurt_Stern_(Schriftsteller)']
#
# Name: ['Erfurt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Erfurt']
#
# Name: ['Hermann Levy']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Levy']
#
# Name: ['Karl Gutzkow']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Gutzkow']
#
# Name: ['Victor Hugo']
# URI: ['http://data.judaicalink.org/data/dbpedia/Victor_Hugo']
#
# Name: ['Abraham Sulzbach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Abraham_Sulzbach']
#
# Name: ['Speyer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Speyer']
#
# Name: ['Albert Salomon Anselm von Rothschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Albert_Salomon_Anselm_von_Rothschild']
#
# Name: ['David Cassel']
# URI: ['http://data.judaicalink.org/data/dbpedia/David_Cassel']
#
# Name: ['Erich Ludwig Loewenthal']
# URI: ['http://data.judaicalink.org/data/dbpedia/Erich_Ludwig_Loewenthal']
#
# Name: ['David Neuhaus']
# URI: ['http://data.judaicalink.org/data/dbpedia/David_Neuhaus']
#
# Name: ['Arnsberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Arnsberg']
#
# Name: ['Perleberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Perleberg']
#
# Name: ['Mark Twain']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mark_Twain']
#
# Name: ['Jacob Rosenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jacob_Rosenheim']
#
# Name: ['New Orleans']
# URI: ['http://data.judaicalink.org/data/dbpedia/New_Orleans']
#
# Name: ['Sydney']
# URI: ['http://data.judaicalink.org/data/dbpedia/Sydney']
#
# Name: ['Selig Schachnowitz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Selig_Schachnowitz']
#
# Name: ['Solomon Birnbaum']
# URI: ['http://data.judaicalink.org/data/dbpedia/Solomon_Birnbaum']
#
# Name: ['Geisenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Geisenheim']
#
# Name: ['Alsfeld']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alsfeld']
#
# Name: ['Koblenz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Koblenz']
#
# Name: ['Hünfeld']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hünfeld']
#
# Name: ['Reims']
# URI: ['http://data.judaicalink.org/data/dbpedia/Reims']
#
# Name: ['Julius Hirsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Julius_Hirsch']
#
# Name: ['Hermann Schiff']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Schiff']
#
# Name: ['Nathan Adler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Nathan_Adler']
#
# Name: ['Mosbach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mosbach']
#
# Name: ['Marcus Tullius Cicero']
# URI: ['http://data.judaicalink.org/data/dbpedia/Marcus_Tullius_Cicero']
#
# Name: ['Werne']
# URI: ['http://data.judaicalink.org/data/dbpedia/Werne']
#
# Name: ['Robert Schumann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Robert_Schumann']
#
# Name: ['Pappenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Pappenheim']
#
# Name: ['Alzenau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alzenau']
#
# Name: ['Uffenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Uffenheim']
#
# Name: ['Landshut']
# URI: ['http://data.judaicalink.org/data/dbpedia/Landshut']
#
# Name: ['Schlüchtern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schlüchtern']
#
# Name: ['Eschwege']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eschwege']
#
# Name: ['Będzin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Będzin']
#
# Name: ['Vallendar']
# URI: ['http://data.judaicalink.org/data/dbpedia/Vallendar']
#
# Name: ['Nachmanides']
# URI: ['http://data.judaicalink.org/data/dbpedia/Nachmanides']
#
# Name: ['Mathilde von Rothschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mathilde_von_Rothschild']
#
# Name: ['Homer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Homer']
#
# Name: ['Conrad Ferdinand Meyer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Conrad_Ferdinand_Meyer']
#
# Name: ['Lübeck']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lübeck']
#
# Name: ['Kaunas']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kaunas']
#
# Name: ['Moses ibn Tibbon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moses_ibn_Tibbon']
#
# Name: ['Hrodna']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hrodna']
#
# Name: ['Raphael Breuer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Raphael_Breuer']
#
# Name: ['Max I. Bodenheimer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_I._Bodenheimer']
#
# Name: ['Nossen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Nossen']
#
# Name: ['Lina Stern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lina_Stern']
#
# Name: ['Melbourne']
# URI: ['http://data.judaicalink.org/data/dbpedia/Melbourne']
#
# Name: ['Katowice']
# URI: ['http://data.judaicalink.org/data/dbpedia/Katowice']
#
# Name: ['Schmalkalden']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schmalkalden']
#
# Name: ['Unna']
# URI: ['http://data.judaicalink.org/data/dbpedia/Unna']
#
# Name: ['Edmond Rothschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Edmond_Rothschild']
#
# Name: ['Bitburg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bitburg']
#
# Name: ['Bruno Bauer (Philosoph)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bruno_Bauer_(Philosoph)']
#
# Name: ['Fränkisch-Crumbach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Fränkisch-Crumbach']
#
# Name: ['Schweinfurt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schweinfurt']
#
# Name: ['Zofingen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Zofingen']
#
# Name: ['Immanuel Kant']
# URI: ['http://data.judaicalink.org/data/dbpedia/Immanuel_Kant']
#
# Name: ['Plauen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Plauen']
#
# Name: ['Bensheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bensheim']
#
# Name: ['Peine']
# URI: ['http://data.judaicalink.org/data/dbpedia/Peine']
#
# Name: ['Izmir']
# URI: ['http://data.judaicalink.org/data/dbpedia/Izmir']
#
# Name: ['Konin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Konin']
#
# Name: ['Elberfeld']
# URI: ['http://data.judaicalink.org/data/dbpedia/Elberfeld']
#
# Name: ['Oberwesel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Oberwesel']
#
# Name: ['Dießen am Ammersee']
# URI: ['http://data.judaicalink.org/data/dbpedia/Dießen_am_Ammersee']
#
# Name: ['Portugal']
# URI: ['http://data.judaicalink.org/data/dbpedia/Portugal']
#
# Name: ['Leopold I. (HRR)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leopold_I._(HRR)']
#
# Name: ['Gotthold Ephraim Lessing']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gotthold_Ephraim_Lessing']
#
# Name: ['Seligenstadt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Seligenstadt']
#
# Name: ['Osterwieck']
# URI: ['http://data.judaicalink.org/data/dbpedia/Osterwieck']
#
# Name: ['Jakob ben Salomo Chabib']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_ben_Salomo_Chabib']
#
# Name: ['Euripides']
# URI: ['http://data.judaicalink.org/data/dbpedia/Euripides']
#
# Name: ['George Eliot']
# URI: ['http://data.judaicalink.org/data/dbpedia/George_Eliot']
#
# Name: ['Seckel Bamberger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Seckel_Bamberger']
#
# Name: ['Metz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Metz']
#
# Name: ['Mordechai Strigler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mordechai_Strigler']
#
# Name: ['Rendsburg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rendsburg']
#
# Name: ['Franz Schubert']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Schubert']
#
# Name: ['Kitzingen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kitzingen']
#
# Name: ['Jonatan ben Usiel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jonatan_ben_Usiel']
#
# Name: ['Alphonse Daudet']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alphonse_Daudet']
#
# Name: ['Bad Ems']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bad_Ems']
#
# Name: ['Anatole France']
# URI: ['http://data.judaicalink.org/data/dbpedia/Anatole_France']
#
# Name: ['Karl Rudolf Seyerlen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Rudolf_Seyerlen']
#
# Name: ['Tarnów']
# URI: ['http://data.judaicalink.org/data/dbpedia/Tarnów']
#
# Name: ['Gabriel Stern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gabriel_Stern']
#
# Name: ['Josef Breuer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Josef_Breuer']
#
# Name: ['Cheb']
# URI: ['http://data.judaicalink.org/data/dbpedia/Cheb']
#
# Name: ['Grit Straßenberger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Grit_Straßenberger']
#
# Name: ['Goslar']
# URI: ['http://data.judaicalink.org/data/dbpedia/Goslar']
#
# Name: ['Lörrach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lörrach']
#
# Name: ['Liepāja']
# URI: ['http://data.judaicalink.org/data/dbpedia/Liepāja']
#
# Name: ['Ludwig Bamberger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Bamberger']
#
# Name: ['Turin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Turin']
#
# Name: ['Frombork']
# URI: ['http://data.judaicalink.org/data/dbpedia/Frombork']
#
# Name: ['Wieliczka']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wieliczka']
#
# Name: ['Tacitus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Tacitus']
#
# Name: ['Eleasar ben Asarja']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eleasar_ben_Asarja']
#
# Name: ['Merzig']
# URI: ['http://data.judaicalink.org/data/dbpedia/Merzig']
#
# Name: ['Hermann Schwab']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Schwab']
#
# Name: ['Kołobrzeg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kołobrzeg']
#
# Name: ['Max von Oppenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_von_Oppenheim']
#
# Name: ['Abraham Bing']
# URI: ['http://data.judaicalink.org/data/dbpedia/Abraham_Bing']
#
# Name: ['Heinrich Heine']
# URI: ['http://data.judaicalink.org/data/dbpedia/Heinrich_Heine']
#
# Name: ['Wilhelm Hauff']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Hauff']
#
# Name: ['Jakob Löwenstein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Löwenstein']
#
# Name: ['Gustav Freytag']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gustav_Freytag']
#
# Name: ['Dreieich']
# URI: ['http://data.judaicalink.org/data/dbpedia/Dreieich']
#
# Name: ['Neu-Isenburg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Neu-Isenburg']
#
# Name: ['Burgpreppach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Burgpreppach']
#
# Name: ['Ludwig van Beethoven']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_van_Beethoven']
#
# Name: ['Prenzlau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Prenzlau']
#
# Name: ['Dillenburg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Dillenburg']
#
# Name: ['Thomas Mann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Thomas_Mann']
#
# Name: ['Hermann Wronker']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Wronker']
#
# Name: ['Elmshorn']
# URI: ['http://data.judaicalink.org/data/dbpedia/Elmshorn']
#
# Name: ['Xenophon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Xenophon']
#
# Name: ["Achad Ha'am"]
# URI: ["http://data.judaicalink.org/data/dbpedia/Achad_Ha'am"]
#
# Name: ['Hans Keilson']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hans_Keilson']
#
# Name: ['Julius Bab']
# URI: ['http://data.judaicalink.org/data/dbpedia/Julius_Bab']
#
# Name: ['Ismar Elbogen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ismar_Elbogen']
#
# Name: ['Jewgeni Jurjewitsch Najer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jewgeni_Jurjewitsch_Najer']
#
# Name: ['Johann Gottfried Herder']
# URI: ['http://data.judaicalink.org/data/dbpedia/Johann_Gottfried_Herder']
#
# Name: ['Moses Mendelssohn']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moses_Mendelssohn']
#
# Name: ['Ludwig Geiger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Geiger']
#
# Name: ['Wilhelm Schäfer (Schriftsteller)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Schäfer_(Schriftsteller)']
#
# Name: ['Alfons Paquet']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alfons_Paquet']
#
# Name: ['Selma Stern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Selma_Stern']
#
# Name: ['Eugen Täubler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eugen_Täubler']
#
# Name: ['Franz Rosenzweig']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Rosenzweig']
#
# Name: ['Hermann Cohen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Cohen']
#
# Name: ['Henrique Lemle']
# URI: ['http://data.judaicalink.org/data/dbpedia/Henrique_Lemle']
#
# Name: ['Mohandas Karamchand Gandhi']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mohandas_Karamchand_Gandhi']
#
# Name: ['Friedrich Thieberger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Thieberger']
#
# Name: ['Max Dienemann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Dienemann']
#
# Name: ['Margarete Susman']
# URI: ['http://data.judaicalink.org/data/dbpedia/Margarete_Susman']
#
# Name: ['Edmond Fleg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Edmond_Fleg']
#
# Name: ['Ernest Renan']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ernest_Renan']
#
# Name: ['Heinrich Zimmern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Heinrich_Zimmern']
#
# Name: ['Max Eschelbacher']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Eschelbacher']
#
# Name: ['Morris Rosenfeld']
# URI: ['http://data.judaicalink.org/data/dbpedia/Morris_Rosenfeld']
#
# Name: ['Theodor Zlocisti']
# URI: ['http://data.judaicalink.org/data/dbpedia/Theodor_Zlocisti']
#
# Name: ['Ignaz Bernstein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ignaz_Bernstein']
#
# Name: ['Odessa']
# URI: ['http://data.judaicalink.org/data/dbpedia/Odessa']
#
# Name: ['Ukraine']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ukraine']
#
# Name: ['Ernst Troeltsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ernst_Troeltsch']
#
# Name: ['William Robertson Smith']
# URI: ['http://data.judaicalink.org/data/dbpedia/William_Robertson_Smith']
#
# Name: ['Alfred Bertholet']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alfred_Bertholet']
#
# Name: ['Kleve']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kleve']
#
# Name: ['Josef Kastein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Josef_Kastein']
#
# Name: ['Martin Buber']
# URI: ['http://data.judaicalink.org/data/dbpedia/Martin_Buber']
#
# Name: ['Perez Hirschbein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Perez_Hirschbein']
#
# Name: ['Leo Hirsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leo_Hirsch']
#
# Name: ['August Rohling']
# URI: ['http://data.judaicalink.org/data/dbpedia/August_Rohling']
#
# Name: ['Theodor Fritsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Theodor_Fritsch']
#
# Name: ['Moses Gaster']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moses_Gaster']
#
# Name: ['Heinrich Graetz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Heinrich_Graetz']
#
# Name: ['Wilhelm Stapel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Stapel']
#
# Name: ['Frederick Hertz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Frederick_Hertz']
#
# Name: ['Baalbek']
# URI: ['http://data.judaicalink.org/data/dbpedia/Baalbek']
#
# Name: ['St. John Ervine']
# URI: ['http://data.judaicalink.org/data/dbpedia/St._John_Ervine']
#
# Name: ['Joseph Gedalja Klausner']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joseph_Gedalja_Klausner']
#
# Name: ['Safed']
# URI: ['http://data.judaicalink.org/data/dbpedia/Safed']
#
# Name: ['Cecil Roth']
# URI: ['http://data.judaicalink.org/data/dbpedia/Cecil_Roth']
#
# Name: ['Arno Nadel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Arno_Nadel']
#
# Name: ['Constantin Brunner']
# URI: ['http://data.judaicalink.org/data/dbpedia/Constantin_Brunner']
#
# Name: ['Hans-Joachim Schoeps']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hans-Joachim_Schoeps']
#
# Name: ['Felix Perles']
# URI: ['http://data.judaicalink.org/data/dbpedia/Felix_Perles']
#
# Name: ['Karl Krumbacher']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Krumbacher']
#
# Name: ['Carl Landauer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Carl_Landauer']
#
# Name: ['Bertha Pappenheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bertha_Pappenheim']
#
# Name: ['Paul Lazarus (Rabbiner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Paul_Lazarus_(Rabbiner)']
#
# Name: ['Annette von Droste-Hülshoff']
# URI: ['http://data.judaicalink.org/data/dbpedia/Annette_von_Droste-Hülshoff']
#
# Name: ['Salomon Maimon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Salomon_Maimon']
#
# Name: ['Marcus Herz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Marcus_Herz']
#
# Name: ['Viktor von Weizsäcker']
# URI: ['http://data.judaicalink.org/data/dbpedia/Viktor_von_Weizsäcker']
#
# Name: ['Siegfried Silberstein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Siegfried_Silberstein']
#
# Name: ['Felix Goldmann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Felix_Goldmann']
#
# Name: ['Sonia Levitin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Sonia_Levitin']
#
# Name: ['Ludwig Feuchtwanger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Feuchtwanger']
#
# Name: ['Nachman Krochmal']
# URI: ['http://data.judaicalink.org/data/dbpedia/Nachman_Krochmal']
#
# Name: ['Joseph Carlebach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joseph_Carlebach']
#
# Name: ['Ernst Cassirer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ernst_Cassirer']
#
# Name: ['Michael Guttmann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Michael_Guttmann']
#
# Name: ['Lothar Rothschild']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lothar_Rothschild']
#
# Name: ['New York City']
# URI: ['http://data.judaicalink.org/data/dbpedia/New_York_City']
#
# Name: ['Le Havre']
# URI: ['http://data.judaicalink.org/data/dbpedia/Le_Havre']
#
# Name: ['Jules Verne']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jules_Verne']
#
# Name: ['Ebed-Melech']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ebed-Melech']
#
# Name: ['Ignaz Maybaum']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ignaz_Maybaum']
#
# Name: ['Rahel Varnhagen von Ense']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rahel_Varnhagen_von_Ense']
#
# Name: ['Max Liebermann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Liebermann']
#
# Name: ['Walther Rathenau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Walther_Rathenau']
#
# Name: ['Eugen Fischer (Mediziner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eugen_Fischer_(Mediziner)']
#
# Name: ['Jozef Israëls']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jozef_Israëls']
#
# Name: ['Franz Landsberger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Landsberger']
#
# Name: ['Alice Salomon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alice_Salomon']
#
# Name: ['Josephine Levy-Rathenau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Josephine_Levy-Rathenau']
#
# Name: ['Buenos Aires']
# URI: ['http://data.judaicalink.org/data/dbpedia/Buenos_Aires']
#
# Name: ['Hans Hinkel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hans_Hinkel']
#
# Name: ['Ernst Simon (Philosoph)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ernst_Simon_(Philosoph)']
#
# Name: ['Samuel Holdheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Samuel_Holdheim']
#
# Name: ['Ilya Gurevich']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ilya_Gurevich']
#
# Name: ['David Friedländer']
# URI: ['http://data.judaicalink.org/data/dbpedia/David_Friedländer']
#
# Name: ['Offenbach am Main']
# URI: ['http://data.judaicalink.org/data/dbpedia/Offenbach_am_Main']
#
# Name: ['Max Wiener']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Wiener']
#
# Name: ['Alfred Stern (Historiker)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alfred_Stern_(Historiker)']
#
# Name: ['Johann Jacoby']
# URI: ['http://data.judaicalink.org/data/dbpedia/Johann_Jacoby']
#
# Name: ['Berthold Auerbach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Berthold_Auerbach']
#
# Name: ['Joseph Süß Oppenheimer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joseph_Süß_Oppenheimer']
#
# Name: ['Gustav Mahler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gustav_Mahler']
#
# Name: ['Rabanus Maurus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rabanus_Maurus']
#
# Name: ['Moritz von Schwind']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moritz_von_Schwind']
#
# Name: ['Lazar Gulkowitsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lazar_Gulkowitsch']
#
# Name: ['Alfred Wiener']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alfred_Wiener']
#
# Name: ['Franz Kafka']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Kafka']
#
# Name: ['Oskar Baum']
# URI: ['http://data.judaicalink.org/data/dbpedia/Oskar_Baum']
#
# Name: ['Moscheh Ya’akov Ben-Gavriêl']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moscheh_Ya’akov_Ben-Gavriêl']
#
# Name: ['Ernst Lissauer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ernst_Lissauer']
#
# Name: ['Schalom Ben-Chorin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schalom_Ben-Chorin']
#
# Name: ['Werner Kraft']
# URI: ['http://data.judaicalink.org/data/dbpedia/Werner_Kraft']
#
# Name: ['Friedrich Torberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Torberg']
#
# Name: ['Heinz Politzer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Heinz_Politzer']
#
# Name: ['Naftali Herz Tur-Sinai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Naftali_Herz_Tur-Sinai']
#
# Name: ['Moritz Gottlieb Saphir']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moritz_Gottlieb_Saphir']
#
# Name: ['Hieronymus Lorm']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hieronymus_Lorm']
#
# Name: ['Jankel Adler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jankel_Adler']
#
# Name: ['Leo Motzkin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leo_Motzkin']
#
# Name: ['Remscheid']
# URI: ['http://data.judaicalink.org/data/dbpedia/Remscheid']
#
# Name: ['Solingen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Solingen']
#
# Name: ['Anton Kippenberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Anton_Kippenberg']
#
# Name: ['Worpswede']
# URI: ['http://data.judaicalink.org/data/dbpedia/Worpswede']
#
# Name: ['Hermann Stehr']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Stehr']
#
# Name: ['Josef Chaim Brenner']
# URI: ['http://data.judaicalink.org/data/dbpedia/Josef_Chaim_Brenner']
#
# Name: ['Erich Stern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Erich_Stern']
#
# Name: ['Karl Wolfskehl']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Wolfskehl']
#
# Name: ['Moses Hess']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moses_Hess']
#
# Name: ['Mönchengladbach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mönchengladbach']
#
# Name: ['Zittau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Zittau']
#
# Name: ['Krefeld']
# URI: ['http://data.judaicalink.org/data/dbpedia/Krefeld']
#
# Name: ['Harry Graf Kessler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Harry_Graf_Kessler']
#
# Name: ['Gotthelf Bergsträßer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gotthelf_Bergsträßer']
#
# Name: ['Paul Heyse']
# URI: ['http://data.judaicalink.org/data/dbpedia/Paul_Heyse']
#
# Name: ['Rudolf Levy']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rudolf_Levy']
#
# Name: ['Granada']
# URI: ['http://data.judaicalink.org/data/dbpedia/Granada']
#
# Name: ['Leopold Zunz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leopold_Zunz']
#
# Name: ['Richard Wagner']
# URI: ['http://data.judaicalink.org/data/dbpedia/Richard_Wagner']
#
# Name: ['Michael Beer (Autor)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Michael_Beer_(Autor)']
#
# Name: ['Fritz Bamberger (Philosoph)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Fritz_Bamberger_(Philosoph)']
#
# Name: ['Helen Rosenau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Helen_Rosenau']
#
# Name: ['Hebron']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hebron']
#
# Name: ['Mohammed Amin al-Husseini']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mohammed_Amin_al-Husseini']
#
# Name: ['Bremerhaven']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bremerhaven']
#
# Name: ['Cuxhaven']
# URI: ['http://data.judaicalink.org/data/dbpedia/Cuxhaven']
#
# Name: ['Gabriel Riesser']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gabriel_Riesser']
#
# Name: ['Benjamin Disraeli']
# URI: ['http://data.judaicalink.org/data/dbpedia/Benjamin_Disraeli']
#
# Name: ['Else Meidner']
# URI: ['http://data.judaicalink.org/data/dbpedia/Else_Meidner']
#
# Name: ['Maximilian von Schwartzkoppen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Maximilian_von_Schwartzkoppen']
#
# Name: ['Dismas']
# URI: ['http://data.judaicalink.org/data/dbpedia/Dismas']
#
# Name: ['Friedrich Delitzsch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Delitzsch']
#
# Name: ['Meyer Isler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Meyer_Isler']
#
# Name: ['Jannai (Dichter)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jannai_(Dichter)']
#
# Name: ['Haguenau']
# URI: ['http://data.judaicalink.org/data/dbpedia/Haguenau']
#
# Name: ['Colmar']
# URI: ['http://data.judaicalink.org/data/dbpedia/Colmar']
#
# Name: ['Josef Karo']
# URI: ['http://data.judaicalink.org/data/dbpedia/Josef_Karo']
#
# Name: ['Alfred Wolfenstein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Alfred_Wolfenstein']
#
# Name: ['Willy Haas']
# URI: ['http://data.judaicalink.org/data/dbpedia/Willy_Haas']
#
# Name: ['Paul Fiebig']
# URI: ['http://data.judaicalink.org/data/dbpedia/Paul_Fiebig']
#
# Name: ['Hans Lietzmann (Theologe)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hans_Lietzmann_(Theologe)']
#
# Name: ['Rudolf Kittel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rudolf_Kittel']
#
# Name: ['Elischa ben Abuja']
# URI: ['http://data.judaicalink.org/data/dbpedia/Elischa_ben_Abuja']
#
# Name: ['Rudolf Frank (Schriftsteller)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rudolf_Frank_(Schriftsteller)']
#
# Name: ['Sigmund Freud']
# URI: ['http://data.judaicalink.org/data/dbpedia/Sigmund_Freud']
#
# Name: ['Erich von Kahler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Erich_von_Kahler']
#
# Name: ['Ricarda Huch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ricarda_Huch']
#
# Name: ['Ludwig Uhland']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Uhland']
#
# Name: ['Friedrich Wilhelm IV.']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Wilhelm_IV.']
#
# Name: ['Haifa']
# URI: ['http://data.judaicalink.org/data/dbpedia/Haifa']
#
# Name: ['Ludwig Holländer (Jurist)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Holländer_(Jurist)']
#
# Name: ['Adolf Kober']
# URI: ['http://data.judaicalink.org/data/dbpedia/Adolf_Kober']
#
# Name: ['Bertha Badt-Strauss']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bertha_Badt-Strauss']
#
# Name: ['Opava']
# URI: ['http://data.judaicalink.org/data/dbpedia/Opava']
#
# Name: ['Ismar Freund']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ismar_Freund']
#
# Name: ['Aleppo']
# URI: ['http://data.judaicalink.org/data/dbpedia/Aleppo']
#
# Name: ['Bruck an der Mur']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bruck_an_der_Mur']
#
# Name: ['Świdnica']
# URI: ['http://data.judaicalink.org/data/dbpedia/Świdnica']
#
# Name: ['Abraham Geiger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Abraham_Geiger']
#
# Name: ['Ludwig Feuerbach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Feuerbach']
#
# Name: ['Gerhart Hauptmann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gerhart_Hauptmann']
#
# Name: ['Wilhelm Wundt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Wundt']
#
# Name: ['Upton Sinclair']
# URI: ['http://data.judaicalink.org/data/dbpedia/Upton_Sinclair']
#
# Name: ['Julius Höxter']
# URI: ['http://data.judaicalink.org/data/dbpedia/Julius_Höxter']
#
# Name: ['Hermann Bahr']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Bahr']
#
# Name: ['Georg Büchner']
# URI: ['http://data.judaicalink.org/data/dbpedia/Georg_Büchner']
#
# Name: ['Friedrich Meinecke']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Meinecke']
#
# Name: ['Arnold Zweig']
# URI: ['http://data.judaicalink.org/data/dbpedia/Arnold_Zweig']
#
# Name: ['Max Scheler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Scheler']
#
# Name: ['Scheveningen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Scheveningen']
#
# Name: ['Pinsk']
# URI: ['http://data.judaicalink.org/data/dbpedia/Pinsk']
#
# Name: ['Szamotuły']
# URI: ['http://data.judaicalink.org/data/dbpedia/Szamotuły']
#
# Name: ['Jakob Wassermann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Wassermann']
#
# Name: ['Solomon Schechter']
# URI: ['http://data.judaicalink.org/data/dbpedia/Solomon_Schechter']
#
# Name: ['Theodor Mommsen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Theodor_Mommsen']
#
# Name: ['Eduard von Hartmann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eduard_von_Hartmann']
#
# Name: ['Trakai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Trakai']
#
# Name: ['Rudolf Borchardt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rudolf_Borchardt']
#
# Name: ['Georg Brandes']
# URI: ['http://data.judaicalink.org/data/dbpedia/Georg_Brandes']
#
# Name: ['Friedrich Gundolf']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Gundolf']
#
# Name: ['Henri Bergson']
# URI: ['http://data.judaicalink.org/data/dbpedia/Henri_Bergson']
#
# Name: ['Glikl bas Judah Leib']
# URI: ['http://data.judaicalink.org/data/dbpedia/Glikl_bas_Judah_Leib']
#
# Name: ['Julien Benda']
# URI: ['http://data.judaicalink.org/data/dbpedia/Julien_Benda']
#
# Name: ['Karl Vorländer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Vorländer']
#
# Name: ['Mumbai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mumbai']
#
# Name: ['Friedrich Schleiermacher']
# URI: ['http://data.judaicalink.org/data/dbpedia/Friedrich_Schleiermacher']
#
# Name: ['E. T. A. Hoffmann']
# URI: ['http://data.judaicalink.org/data/dbpedia/E._T._A._Hoffmann']
#
# Name: ['Madrid']
# URI: ['http://data.judaicalink.org/data/dbpedia/Madrid']
#
# Name: ['Engelbert Krebs']
# URI: ['http://data.judaicalink.org/data/dbpedia/Engelbert_Krebs']
#
# Name: ['Peter Altenberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Peter_Altenberg']
#
# Name: ['Karl Kraus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Karl_Kraus']
#
# Name: ['Abimelech']
# URI: ['http://data.judaicalink.org/data/dbpedia/Abimelech']
#
# Name: ['Carl Gebhardt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Carl_Gebhardt']
#
# Name: ['Ludwig Basnizki']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ludwig_Basnizki']
#
# Name: ['Kurt Zielenziger']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kurt_Zielenziger']
#
# Name: ['Else Lasker-Schüler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Else_Lasker-Schüler']
#
# Name: ['Schalom Asch']
# URI: ['http://data.judaicalink.org/data/dbpedia/Schalom_Asch']
#
# Name: ['Joachim Prinz (Rabbiner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joachim_Prinz_(Rabbiner)']
#
# Name: ['Stefan Zweig']
# URI: ['http://data.judaicalink.org/data/dbpedia/Stefan_Zweig']
#
# Name: ['George Gordon Byron']
# URI: ['http://data.judaicalink.org/data/dbpedia/George_Gordon_Byron']
#
# Name: ['Opatów']
# URI: ['http://data.judaicalink.org/data/dbpedia/Opatów']
#
# Name: ['Hugo Grotius']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hugo_Grotius']
#
# Name: ['Origenes']
# URI: ['http://data.judaicalink.org/data/dbpedia/Origenes']
#
# Name: ['Simon de Vries']
# URI: ['http://data.judaicalink.org/data/dbpedia/Simon_de_Vries']
#
# Name: ['Shanghai']
# URI: ['http://data.judaicalink.org/data/dbpedia/Shanghai']
#
# Name: ['Jehuda ha-Levi']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jehuda_ha-Levi']
#
# Name: ['Moritz Lazarus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Moritz_Lazarus']
#
# Name: ['Adalbert Stifter']
# URI: ['http://data.judaicalink.org/data/dbpedia/Adalbert_Stifter']
#
# Name: ['Peter Brunner (Theologe)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Peter_Brunner_(Theologe)']
#
# Name: ['Henriette Herz']
# URI: ['http://data.judaicalink.org/data/dbpedia/Henriette_Herz']
#
# Name: ['Bettina von Arnim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bettina_von_Arnim']
#
# Name: ['Achim von Arnim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Achim_von_Arnim']
#
# Name: ['Troyes']
# URI: ['http://data.judaicalink.org/data/dbpedia/Troyes']
#
# Name: ['Arthur Schopenhauer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Arthur_Schopenhauer']
#
# Name: ['Aischylos']
# URI: ['http://data.judaicalink.org/data/dbpedia/Aischylos']
#
# Name: ['Else Schubert-Christaller']
# URI: ['http://data.judaicalink.org/data/dbpedia/Else_Schubert-Christaller']
#
# Name: ['Max Weber']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Weber']
#
# Name: ['Huningue']
# URI: ['http://data.judaicalink.org/data/dbpedia/Huningue']
#
# Name: ['Raffael']
# URI: ['http://data.judaicalink.org/data/dbpedia/Raffael']
#
# Name: ['Flinders Petrie']
# URI: ['http://data.judaicalink.org/data/dbpedia/Flinders_Petrie']
#
# Name: ['Wilhelm Spiegelberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Wilhelm_Spiegelberg']
#
# Name: ['Max Brod']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Brod']
#
# Name: ['Jesus Christus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jesus_Christus']
#
# Name: ['Eduard Meyer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eduard_Meyer']
#
# Name: ['Adolf von Harnack']
# URI: ['http://data.judaicalink.org/data/dbpedia/Adolf_von_Harnack']
#
# Name: ['Julius Fürst (Orientalist)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Julius_Fürst_(Orientalist)']
#
# Name: ['Abraham Mapu']
# URI: ['http://data.judaicalink.org/data/dbpedia/Abraham_Mapu']
#
# Name: ['Fanny Lewald']
# URI: ['http://data.judaicalink.org/data/dbpedia/Fanny_Lewald']
#
# Name: ['Kurt Wolff (Verleger)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kurt_Wolff_(Verleger)']
#
# Name: ['Franz Kobler']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Kobler']
#
# Name: ['Theodor Herzl']
# URI: ['http://data.judaicalink.org/data/dbpedia/Theodor_Herzl']
#
# Name: ['Max Grunwald']
# URI: ['http://data.judaicalink.org/data/dbpedia/Max_Grunwald']
#
# Name: ['Isaak Heinemann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Isaak_Heinemann']
#
# Name: ['Jehuda ha-Nasi']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jehuda_ha-Nasi']
#
# Name: ['Chasdai ibn Schaprut']
# URI: ['http://data.judaicalink.org/data/dbpedia/Chasdai_ibn_Schaprut']
#
# Name: ['Rosheim']
# URI: ['http://data.judaicalink.org/data/dbpedia/Rosheim']
#
# Name: ['Kurt Pinthus']
# URI: ['http://data.judaicalink.org/data/dbpedia/Kurt_Pinthus']
#
# Name: ['Uriel da Costa']
# URI: ['http://data.judaicalink.org/data/dbpedia/Uriel_da_Costa']
#
# Name: ['Erich Gottgetreu']
# URI: ['http://data.judaicalink.org/data/dbpedia/Erich_Gottgetreu']
#
# Name: ['Joseph Roth']
# URI: ['http://data.judaicalink.org/data/dbpedia/Joseph_Roth']
#
# Name: ['Hermann Vogelstein']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Vogelstein']
#
# Name: ['Leone da Modena']
# URI: ['http://data.judaicalink.org/data/dbpedia/Leone_da_Modena']
#
# Name: ['Franz Oppenheimer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Oppenheimer']
#
# Name: ['Düren']
# URI: ['http://data.judaicalink.org/data/dbpedia/Düren']
#
# Name: ['Arrian']
# URI: ['http://data.judaicalink.org/data/dbpedia/Arrian']
#
# Name: ['Gerson Stern']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gerson_Stern']
#
# Name: ['Höxter']
# URI: ['http://data.judaicalink.org/data/dbpedia/Höxter']
#
# Name: ['Hugo von Hofmannsthal']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hugo_von_Hofmannsthal']
#
# Name: ['Mark Wischnitzer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Mark_Wischnitzer']
#
# Name: ['Umberto Cassuto']
# URI: ['http://data.judaicalink.org/data/dbpedia/Umberto_Cassuto']
#
# Name: ['Elias Bickermann']
# URI: ['http://data.judaicalink.org/data/dbpedia/Elias_Bickermann']
#
# Name: ['Gustav Landauer']
# URI: ['http://data.judaicalink.org/data/dbpedia/Gustav_Landauer']
#
# Name: ['Jacob Burckhardt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jacob_Burckhardt']
#
# Name: ['Nehemia Anton Nobel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Nehemia_Anton_Nobel']
#
# Name: ['Eugen Fuchs (Jurist)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Eugen_Fuchs_(Jurist)']
#
# Name: ['Arthur Eloesser']
# URI: ['http://data.judaicalink.org/data/dbpedia/Arthur_Eloesser']
#
# Name: ['Jacob Bernays']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jacob_Bernays']
#
# Name: ['Walter Windfuhr']
# URI: ['http://data.judaicalink.org/data/dbpedia/Walter_Windfuhr']
#
# Name: ['Lujo Brentano']
# URI: ['http://data.judaicalink.org/data/dbpedia/Lujo_Brentano']
#
# Name: ['Franz Werfel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Franz_Werfel']
#
# Name: ['Hermann Gunkel']
# URI: ['http://data.judaicalink.org/data/dbpedia/Hermann_Gunkel']
#
# Name: ['Minsk']
# URI: ['http://data.judaicalink.org/data/dbpedia/Minsk']
#
# Name: ['Berthold Goldschmidt']
# URI: ['http://data.judaicalink.org/data/dbpedia/Berthold_Goldschmidt']
#
# Name: ['Anton Pawlowitsch Tschechow']
# URI: ['http://data.judaicalink.org/data/dbpedia/Anton_Pawlowitsch_Tschechow']
#
# Name: ['Emil Ludwig']
# URI: ['http://data.judaicalink.org/data/dbpedia/Emil_Ludwig']
#
# Name: ['Jakob Guttmann (Rabbiner)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Guttmann_(Rabbiner)']
#
# Name: ['Jacob Jacobson']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jacob_Jacobson']
#
# Name: ['Jakob Schönberg']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jakob_Schönberg']
#
# Name: ['Jehuda Leib Gordon']
# URI: ['http://data.judaicalink.org/data/dbpedia/Jehuda_Leib_Gordon']
#
# Name: ['Herman Grimm']
# URI: ['http://data.judaicalink.org/data/dbpedia/Herman_Grimm']
#
# Name: ['Judah Löw']
# URI: ['http://data.judaicalink.org/data/dbpedia/Judah_Löw']
#
# Name: ['Menachem Ussishkin']
# URI: ['http://data.judaicalink.org/data/dbpedia/Menachem_Ussishkin']
#
# Name: ['Witzenhausen']
# URI: ['http://data.judaicalink.org/data/dbpedia/Witzenhausen']
#
# Name: ['Ezriel Carlebach']
# URI: ['http://data.judaicalink.org/data/dbpedia/Ezriel_Carlebach']
#
# Name: ['Tunis']
# URI: ['http://data.judaicalink.org/data/dbpedia/Tunis']
#
# Name: ['Bruno Italiener']
# URI: ['http://data.judaicalink.org/data/dbpedia/Bruno_Italiener']
#
# Name: ['Amora (Judentum)']
# URI: ['http://data.judaicalink.org/data/dbpedia/Amora_(Judentum)']
#
# Name: ['Josel von Rosheim']
# ...
#
# Name: Winchester
# URI: http://data.judaicalink.org/data/dbpedia/Winchester
#
# Name: Werner Weinberg
# URI: http://data.judaicalink.org/data/dbpedia/Werner_Weinberg
#
# Name: The Bund
# URI: http://data.judaicalink.org/data/dbpedia/The_Bund
#
# Name: El Lissitzky
# URI: http://data.judaicalink.org/data/dbpedia/El_Lissitzky
#
# Name: Švenčionys
# URI: http://data.judaicalink.org/data/dbpedia/Švenčionys
#
# Name: Joseph Lateiner
# URI: http://data.judaicalink.org/data/dbpedia/Joseph_Lateiner
#
# Name: Ruth Rewald
# URI: http://data.judaicalink.org/data/dbpedia/Ruth_Rewald
#
# Name: Klaus Schickert
# URI: http://data.judaicalink.org/data/dbpedia/Klaus_Schickert
#
# Name: John Heartfield
# URI: http://data.judaicalink.org/data/dbpedia/John_Heartfield
#
# Name: Victor Moritz Goldschmidt
# URI: http://data.judaicalink.org/data/dbpedia/Victor_Moritz_Goldschmidt
#
# Name: Irwin Shaw
# URI: http://data.judaicalink.org/data/dbpedia/Irwin_Shaw
#
# Name: Uwe Israel
# URI: http://data.judaicalink.org/data/dbpedia/Uwe_Israel
#
# Name: Lorand Fenyves
# URI: http://data.judaicalink.org/data/dbpedia/Lorand_Fenyves
#
# Name: Lewis Strauss
# URI: http://data.judaicalink.org/data/dbpedia/Lewis_Strauss
#
# Name: Bad Essen
# URI: http://data.judaicalink.org/data/dbpedia/Bad_Essen
#
# Name: Eugene V. Debs
# URI: http://data.judaicalink.org/data/dbpedia/Eugene_V._Debs
#
# Name: Dovid Katz
# URI: http://data.judaicalink.org/data/dbpedia/Dovid_Katz
#
# Name: Totnes
# URI: http://data.judaicalink.org/data/dbpedia/Totnes
#
# Name: Ilse Weber
# URI: http://data.judaicalink.org/data/dbpedia/Ilse_Weber
#
# Name: Gustav Gabriel Cohen
# URI: http://data.judaicalink.org/data/dbpedia/Gustav_Gabriel_Cohen
#
# Name: Heinz Mosche Graupe
# URI: http://data.judaicalink.org/data/dbpedia/Heinz_Mosche_Graupe
#
# Name: Alfréd Hajós
# URI: http://data.judaicalink.org/data/dbpedia/Alfréd_Hajós
#
# Name: Carola Stern
# URI: http://data.judaicalink.org/data/dbpedia/Carola_Stern
#
# Name: Karsin
# URI: http://data.judaicalink.org/data/dbpedia/Karsin
#
# Name: Chaim Soutine
# URI: http://data.judaicalink.org/data/dbpedia/Chaim_Soutine
#
# Name: Gerhard Zadek
# URI: http://data.judaicalink.org/data/dbpedia/Gerhard_Zadek
#
# Name: Herbert Scurla
# URI: http://data.judaicalink.org/data/dbpedia/Herbert_Scurla
#
# Name: Chaville
# URI: http://data.judaicalink.org/data/dbpedia/Chaville
#
# Name: Pavel Sticha
# URI: http://data.judaicalink.org/data/dbpedia/Pavel_Sticha
#
# Name: Furio Jesi
# URI: http://data.judaicalink.org/data/dbpedia/Furio_Jesi
#
# Name: Hermann Ostfeld
# URI: http://data.judaicalink.org/data/dbpedia/Hermann_Ostfeld
#
# Name: Rheda-Wiedenbrück
# URI: http://data.judaicalink.org/data/dbpedia/Rheda-Wiedenbrück
#
# Name: Julius Martow
# URI: http://data.judaicalink.org/data/dbpedia/Julius_Martow
#
# Name: Gillian Rose
# URI: http://data.judaicalink.org/data/dbpedia/Gillian_Rose
#
# Name: Jean Wahl
# URI: http://data.judaicalink.org/data/dbpedia/Jean_Wahl
#
# Name: Ruth Schönthal
# URI: http://data.judaicalink.org/data/dbpedia/Ruth_Schönthal
#
# Name: Hannes Stein
# URI: http://data.judaicalink.org/data/dbpedia/Hannes_Stein
#
# Name: Johann Martin Bernatz
# URI: http://data.judaicalink.org/data/dbpedia/Johann_Martin_Bernatz
#
# Name: Kcynia
# URI: http://data.judaicalink.org/data/dbpedia/Kcynia
#
# Name: Wjatscheslaw Iwanowitsch Iwanow
# URI: http://data.judaicalink.org/data/dbpedia/Wjatscheslaw_Iwanowitsch_Iwanow
#
# Name: Volkmar Andreae
# URI: http://data.judaicalink.org/data/dbpedia/Volkmar_Andreae
#
# Name: Clara Grunwald
# URI: http://data.judaicalink.org/data/dbpedia/Clara_Grunwald
#
# Name: Levin Kipnis
# URI: http://data.judaicalink.org/data/dbpedia/Levin_Kipnis
#
# Name: Kurt Goldstein (Journalist)
# URI: http://data.judaicalink.org/data/dbpedia/Kurt_Goldstein_(Journalist)
#
# Name: Karl Theodor (Pfalz und Bayern)
# URI: http://data.judaicalink.org/data/dbpedia/Karl_Theodor_(Pfalz_und_Bayern)
#
# Name: Walther Eichrodt
# URI: http://data.judaicalink.org/data/dbpedia/Walther_Eichrodt
#
# Name: Hugo Wast
# URI: http://data.judaicalink.org/data/dbpedia/Hugo_Wast
#
# Name: Eliahu Ben-Elissar
# URI: http://data.judaicalink.org/data/dbpedia/Eliahu_Ben-Elissar
#
# Name: Ludwig Rellstab (Dichter)
# URI: http://data.judaicalink.org/data/dbpedia/Ludwig_Rellstab_(Dichter)
#
# Name: Reipoltskirchen
# URI: http://data.judaicalink.org/data/dbpedia/Reipoltskirchen
#
# Name: Arnold Bennett
# URI: http://data.judaicalink.org/data/dbpedia/Arnold_Bennett
#
# Name: Ossip Bernstein
# URI: http://data.judaicalink.org/data/dbpedia/Ossip_Bernstein
#
# Name: Bilbao
# URI: http://data.judaicalink.org/data/dbpedia/Bilbao
#
# Name: Isaac Uziel
# URI: http://data.judaicalink.org/data/dbpedia/Isaac_Uziel
#
# Name: Jonathan Israel
# URI: http://data.judaicalink.org/data/dbpedia/Jonathan_Israel
#
# Name: Aaron Hyman
# URI: http://data.judaicalink.org/data/dbpedia/Aaron_Hyman
#
# Name: Georg August Detharding
# URI: http://data.judaicalink.org/data/dbpedia/Georg_August_Detharding
#
# Name: Ladbergen
# URI: http://data.judaicalink.org/data/dbpedia/Ladbergen
#
# Name: Philipp Jakob Heisler
# URI: http://data.judaicalink.org/data/dbpedia/Philipp_Jakob_Heisler
#
# Name: Alexander Alexandrowitsch Aljechin
# URI: http://data.judaicalink.org/data/dbpedia/Alexander_Alexandrowitsch_Aljechin
#
# Name: Žiga Hirschler
# URI: http://data.judaicalink.org/data/dbpedia/Žiga_Hirschler
# Name: Zollikon
# URI: http://data.judaicalink.org/data/dbpedia/Zollikon
#
# Name: Honfleur
# URI: http://data.judaicalink.org/data/dbpedia/Honfleur
#
# Name: Hans Rodenberg
# URI: http://data.judaicalink.org/data/dbpedia/Hans_Rodenberg
#
# Name: Heinz Kindermann (Theaterforscher)
# URI: http://data.judaicalink.org/data/dbpedia/Heinz_Kindermann_(Theaterforscher)
#
# Name: Attnang-Puchheim
# URI: http://data.judaicalink.org/data/dbpedia/Attnang-Puchheim
#
# Name: Odense
# URI: http://data.judaicalink.org/data/dbpedia/Odense
#
# Name: Tuszyn
# URI: http://data.judaicalink.org/data/dbpedia/Tuszyn
#
# Name: Karol Sidon
# URI: http://data.judaicalink.org/data/dbpedia/Karol_Sidon
#
# Name: Bruno Bettelheim
# URI: http://data.judaicalink.org/data/dbpedia/Bruno_Bettelheim
#
# Name: Johann Friedrich Herbart
# URI: http://data.judaicalink.org/data/dbpedia/Johann_Friedrich_Herbart
#
# Name: Uwe Berger
# URI: http://data.judaicalink.org/data/dbpedia/Uwe_Berger
#
# Name: Hendaye
# URI: http://data.judaicalink.org/data/dbpedia/Hendaye
#
# Name: Kotlas
# URI: http://data.judaicalink.org/data/dbpedia/Kotlas
#
# Name: Ludwigslust
# URI: http://data.judaicalink.org/data/dbpedia/Ludwigslust
#
# Name: Irene Awret
# URI: http://data.judaicalink.org/data/dbpedia/Irene_Awret
#
# Name: Michael Pammer
# URI: http://data.judaicalink.org/data/dbpedia/Michael_Pammer
#
# Name: Solikamsk
# URI: http://data.judaicalink.org/data/dbpedia/Solikamsk
#
# Name: Krivany
# URI: http://data.judaicalink.org/data/dbpedia/Krivany
#
# Name: Minna Lachs
# URI: http://data.judaicalink.org/data/dbpedia/Minna_Lachs
#
# Name: David Gelernter
# URI: http://data.judaicalink.org/data/dbpedia/David_Gelernter
#
# Name: Friedrich Wetter
# URI: http://data.judaicalink.org/data/dbpedia/Friedrich_Wetter
#
# Name: Hans von Arnim (Philologe)
# URI: http://data.judaicalink.org/data/dbpedia/Hans_von_Arnim_(Philologe)
#
# Name: Karl Pfeifer (Journalist)
# URI: http://data.judaicalink.org/data/dbpedia/Karl_Pfeifer_(Journalist)
#
# Name: Montargis
# URI: http://data.judaicalink.org/data/dbpedia/Montargis
#
# Name: Helbra
# URI: http://data.judaicalink.org/data/dbpedia/Helbra
#
# Name: Georg Götze
# URI: http://data.judaicalink.org/data/dbpedia/Georg_Götze
#
# Name: Hans Arp
# URI: http://data.judaicalink.org/data/dbpedia/Hans_Arp
#
# Name: Felix Römer (Historiker)
# URI: http://data.judaicalink.org/data/dbpedia/Felix_Römer_(Historiker)
#
# Name: Paide
# URI: http://data.judaicalink.org/data/dbpedia/Paide
#
# Name: Sergei Alexandrowitsch Jessenin
# URI: http://data.judaicalink.org/data/dbpedia/Sergei_Alexandrowitsch_Jessenin
#
# Name: Carl Grädener
# URI: http://data.judaicalink.org/data/dbpedia/Carl_Grädener
#
# Name: David Grossman
# URI: http://data.judaicalink.org/data/dbpedia/David_Grossman
#
# Name: Schoppernau
# URI: http://data.judaicalink.org/data/dbpedia/Schoppernau
#
# Name: Kościan
# URI: http://data.judaicalink.org/data/dbpedia/Kościan
#
# Name: Walter Dietrich
# URI: http://data.judaicalink.org/data/dbpedia/Walter_Dietrich
#
# Name: Béla Révész (Schriftsteller)
# URI: http://data.judaicalink.org/data/dbpedia/Béla_Révész_(Schriftsteller)
#
# Name: Sterlitamak
# URI: http://data.judaicalink.org/data/dbpedia/Sterlitamak
#
# Name: Karl Doehring
# URI: http://data.judaicalink.org/data/dbpedia/Karl_Doehring
#
# Name: Pierre Montet
# URI: http://data.judaicalink.org/data/dbpedia/Pierre_Montet
#
# Name: Hans Schweikart
# URI: http://data.judaicalink.org/data/dbpedia/Hans_Schweikart
#
# Name: Henri van Kol
# URI: http://data.judaicalink.org/data/dbpedia/Henri_van_Kol
#
# Name: Fritz Keller (Historiker)
# URI: http://data.judaicalink.org/data/dbpedia/Fritz_Keller_(Historiker)
#
# Name: Friedrich Kiesler
# URI: http://data.judaicalink.org/data/dbpedia/Friedrich_Kiesler
#
# Name: Herta Reich
# URI: http://data.judaicalink.org/data/dbpedia/Herta_Reich
#
# Name: Bielsk Podlaski
# URI: http://data.judaicalink.org/data/dbpedia/Bielsk_Podlaski
#
# Name: Viktor Christian
# URI: http://data.judaicalink.org/data/dbpedia/Viktor_Christian
#
# Name: Ergoldsbach
# URI: http://data.judaicalink.org/data/dbpedia/Ergoldsbach
#
# Name: Otto Neugebauer
# URI: http://data.judaicalink.org/data/dbpedia/Otto_Neugebauer
#
# Name: Steyregg
# URI: http://data.judaicalink.org/data/dbpedia/Steyregg
#
# Name: Faisal I.
# URI: http://data.judaicalink.org/data/dbpedia/Faisal_I.
#
# Name: Leonid Leonidowitsch Sabanejew
# URI: http://data.judaicalink.org/data/dbpedia/Leonid_Leonidowitsch_Sabanejew
#
# Name: Richard Meier (Architekt)
# URI: http://data.judaicalink.org/data/dbpedia/Richard_Meier_(Architekt)
#
# Name: Viktor Ullmann
# URI: http://data.judaicalink.org/data/dbpedia/Viktor_Ullmann
#
# Name: Cloppenburg
# URI: http://data.judaicalink.org/data/dbpedia/Cloppenburg
#
# Name: Hermann Kinder
# URI: http://data.judaicalink.org/data/dbpedia/Hermann_Kinder
#
# Name: Salzburg
# URI: http://data.judaicalink.org/data/dbpedia/Salzburg
#
# Name: Otto Hauser (Autor)
# URI: http://data.judaicalink.org/data/dbpedia/Otto_Hauser_(Autor)
#
# Name: Sankt Michael in Obersteiermark
# URI: http://data.judaicalink.org/data/dbpedia/Sankt_Michael_in_Obersteiermark
#
# Name: Stefan Żeromski
# URI: http://data.judaicalink.org/data/dbpedia/Stefan_Żeromski
#
# Name: Friedrich Markus Huebner
# URI: http://data.judaicalink.org/data/dbpedia/Friedrich_Markus_Huebner
#
# Name: Korop
# URI: http://data.judaicalink.org/data/dbpedia/Korop
#
# Name: Hans Krása
# URI: http://data.judaicalink.org/data/dbpedia/Hans_Krása
#
# Name: Hainewalde
# URI: http://data.judaicalink.org/data/dbpedia/Hainewalde
#
# Name: Friedrich Bülau
# URI: http://data.judaicalink.org/data/dbpedia/Friedrich_Bülau
#
# Name: George Kaiser
# URI: http://data.judaicalink.org/data/dbpedia/George_Kaiser
#
# Name: Gérard Blitz (Unternehmer)
# URI: http://data.judaicalink.org/data/dbpedia/Gérard_Blitz_(Unternehmer)
#
# Name: Tristan Tzara
# URI: http://data.judaicalink.org/data/dbpedia/Tristan_Tzara
#
# Name: Marie Pappenheim
# URI: http://data.judaicalink.org/data/dbpedia/Marie_Pappenheim
#
# Name: Henning Graf Reventlow
# URI: http://data.judaicalink.org/data/dbpedia/Henning_Graf_Reventlow
#
# Name: Nisroch
# URI: http://data.judaicalink.org/data/dbpedia/Nisroch
#
# Name: Preußisch Oldendorf
# URI: http://data.judaicalink.org/data/dbpedia/Preußisch_Oldendorf
#
# Name: Sigtuna
# URI: http://data.judaicalink.org/data/dbpedia/Sigtuna
#
# Name: Victor Hollaender
# URI: http://data.judaicalink.org/data/dbpedia/Victor_Hollaender
#
# Name: Karl Philipp Conz
# URI: http://data.judaicalink.org/data/dbpedia/Karl_Philipp_Conz
#
# Name: Aukrug
# URI: http://data.judaicalink.org/data/dbpedia/Aukrug
#
# Name: Joseph Ettedgui
# URI: http://data.judaicalink.org/data/dbpedia/Joseph_Ettedgui
#
# Name: Martin Geier
# URI: http://data.judaicalink.org/data/dbpedia/Martin_Geier
#
# Name: Klaus-Gunther Wesseling
# URI: http://data.judaicalink.org/data/dbpedia/Klaus-Gunther_Wesseling
#
# Name: Valentin Thalhofer
# URI: http://data.judaicalink.org/data/dbpedia/Valentin_Thalhofer
#
# Name: Karl Georg von Raumer (Geologe)
# URI: http://data.judaicalink.org/data/dbpedia/Karl_Georg_von_Raumer_(Geologe)
#
# Name: Johann Gottlieb Theophil Bosseck
# URI: http://data.judaicalink.org/data/dbpedia/Johann_Gottlieb_Theophil_Bosseck
#
# Name: Augustin Calmet
# URI: http://data.judaicalink.org/data/dbpedia/Augustin_Calmet
#
# Name: Irpin
# URI: http://data.judaicalink.org/data/dbpedia/Irpin
#
# Name: Jehuda de Mordechai Cassuto
# URI: http://data.judaicalink.org/data/dbpedia/Jehuda_de_Mordechai_Cassuto
#
# Name: Heiligengrabe
# URI: http://data.judaicalink.org/data/dbpedia/Heiligengrabe
#
# Name: Noah Gordon
# URI: http://data.judaicalink.org/data/dbpedia/Noah_Gordon
#
# Name: Caspar Ziegler
# URI: http://data.judaicalink.org/data/dbpedia/Caspar_Ziegler
#
# Name: Arnaldo Momigliano
# URI: http://data.judaicalink.org/data/dbpedia/Arnaldo_Momigliano
#
# Name: Johann Christoph Harenberg
# URI: http://data.judaicalink.org/data/dbpedia/Johann_Christoph_Harenberg
#
# Name: Johann Gottfried Tympe
# URI: http://data.judaicalink.org/data/dbpedia/Johann_Gottfried_Tympe
#
# Name: Christian Benedikt Michaelis
# URI: http://data.judaicalink.org/data/dbpedia/Christian_Benedikt_Michaelis
#
# Name: Christoph August Heumann
# URI: http://data.judaicalink.org/data/dbpedia/Christoph_August_Heumann
#
# Name: Christian Gottlieb Gmelin
# URI: http://data.judaicalink.org/data/dbpedia/Christian_Gottlieb_Gmelin
#
# Name: Hubert Schiel
# URI: http://data.judaicalink.org/data/dbpedia/Hubert_Schiel
#
# Name: Hans Jakob Christoffel von Grimmelshausen
# URI: http://data.judaicalink.org/data/dbpedia/Hans_Jakob_Christoffel_von_Grimmelshausen
#
# Name: Johann Joachim Bellermann
# URI: http://data.judaicalink.org/data/dbpedia/Johann_Joachim_Bellermann
#
# Name: Friedrich II. (Hessen-Kassel)
# URI: http://data.judaicalink.org/data/dbpedia/Friedrich_II._(Hessen-Kassel)
#
# Name: Thomas Harlan
# URI: http://data.judaicalink.org/data/dbpedia/Thomas_Harlan
#
# Name: David Kimche
# URI: http://data.judaicalink.org/data/dbpedia/David_Kimche
#
# Name: Annemarie Schimmel
# URI: http://data.judaicalink.org/data/dbpedia/Annemarie_Schimmel
#
# Name: Uzi Gal
# URI: http://data.judaicalink.org/data/dbpedia/Uzi_Gal
#
# Name: Veit Wyler
# URI: http://data.judaicalink.org/data/dbpedia/Veit_Wyler
#
# Name: Bergneustadt
# URI: http://data.judaicalink.org/data/dbpedia/Bergneustadt
#
# Name: Dietrich Wetzel
# URI: http://data.judaicalink.org/data/dbpedia/Dietrich_Wetzel
#
# Name: Dietrich Goldschmidt
# URI: http://data.judaicalink.org/data/dbpedia/Dietrich_Goldschmidt
#
# Name: Avi Cohen
# URI: http://data.judaicalink.org/data/dbpedia/Avi_Cohen
#
# Name: Paul Éluard
# URI: http://data.judaicalink.org/data/dbpedia/Paul_Éluard
#
# Name: Hans-Werner Bartsch
# URI: http://data.judaicalink.org/data/dbpedia/Hans-Werner_Bartsch
#
# Name: Alice Rühle-Gerstel
# URI: http://data.judaicalink.org/data/dbpedia/Alice_Rühle-Gerstel
#
# Name: Ernst Falkbeer
# URI: http://data.judaicalink.org/data/dbpedia/Ernst_Falkbeer
#
# Name: Rudolf Schäfer (Historiker)
# URI: http://data.judaicalink.org/data/dbpedia/Rudolf_Schäfer_(Historiker)
#
# Name: Carl Jacob Burckhardt
# URI: http://data.judaicalink.org/data/dbpedia/Carl_Jacob_Burckhardt
#
# Name: Rolf Kralovitz
# URI: http://data.judaicalink.org/data/dbpedia/Rolf_Kralovitz
#
# Name: Ernst Diehl (Philologe)
# URI: http://data.judaicalink.org/data/dbpedia/Ernst_Diehl_(Philologe)
#
# Name: John Evelyn
# URI: http://data.judaicalink.org/data/dbpedia/John_Evelyn
#
# Name: Elisabeth von Österreich-Ungarn
# URI: http://data.judaicalink.org/data/dbpedia/Elisabeth_von_Österreich-Ungarn
#
# Name: Friedrich Wilhelm Carl Umbreit
# URI: http://data.judaicalink.org/data/dbpedia/Friedrich_Wilhelm_Carl_Umbreit
#
# Name: Douglas Reed
# URI: http://data.judaicalink.org/data/dbpedia/Douglas_Reed
#
# Name: André Parrot
# URI: http://data.judaicalink.org/data/dbpedia/André_Parrot
#
# Name: Herta Müller
# URI: http://data.judaicalink.org/data/dbpedia/Herta_Müller
#
# Name: Arthur de Gobineau
# URI: http://data.judaicalink.org/data/dbpedia/Arthur_de_Gobineau
#
# Name: Wolfgang Menzel (Pädagoge)
# URI: http://data.judaicalink.org/data/dbpedia/Wolfgang_Menzel_(Pädagoge)
#
# Name: Georg Ludwig Kriegk
# URI: http://data.judaicalink.org/data/dbpedia/Georg_Ludwig_Kriegk
#
# Name: Gottfried Reinhardt
# URI: http://data.judaicalink.org/data/dbpedia/Gottfried_Reinhardt
#
# Name: Santok
# URI: http://data.judaicalink.org/data/dbpedia/Santok
