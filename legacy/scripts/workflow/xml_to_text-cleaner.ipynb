# %% [markdown]
# # XML to TXT
#
# This script generates TXT files from XML files

# %%
import os, json, pprint, time
from xml.etree import ElementTree as ET

import re
import unicodedata

WHITESPACE_RE = re.compile(r"\s+")

root = "/data/cm/"
xml_root = "/data/cm/data/xml/"

# %%
def get_zeitschrift_struktur(path, zs_number):
    print("Zeitschrift:", zs_number, end="\n\n")
    for jahrgang in os.listdir(path+zs_number+"/"+zs_number+"/"):
        print("Jahrgang:", end=" ")
        print(jahrgang)
        print("Hefte:")
        for heft in os.listdir(path+zs_number+"/"+zs_number+"/"+jahrgang+"/"):
            print(heft, end=", ")
            seiten = len(os.listdir(path+zs_number+"/"+zs_number+"/"+jahrgang+"/"+heft))
            print(seiten, "Seiten.")
    print()
    
def xml_to_page(tree):
    # input: page parsed xml tree
    # output: 
    # page --> paragraphs --> lines
    # [[[line1], [line2]], [[line1], [line2]]] etc.
    page = []
    line = []
    par = []
    for node in tree.iter():
        if node.tag.endswith('charParams'):
            line.append(node.text)

        elif node.tag.endswith('line') and line != []:
            par.append(line)
            line = []
        elif node.tag.endswith('par') and par != []:
            page.append(par)
            par = []
    return(page)

def page_blocks_to_text(page_blocks):
    # input: output of xml_to_page
    # output: page as plain text
    text_page = ""
    for par in page_blocks:
        text_par = ""
        for line in par:
            # apparently sometimes line happens to be [None], then...
            if None in line:
                line = [el for el in line if el != None]
            
            text_line = "".join(line).strip()
            text_par += " "
            text_par += text_line
        text_page += text_par
    text_page = text_page.replace("¬ ", "").replace("- ", "").replace("= ", "").replace("^ ", "").strip()
    text_page = text_page.replace(" ;", ";").replace(" ?", "?").replace("•", "")
    text_page = text_page.replace("    ", " ").replace("   ", " ").replace("  ", " ")
    
    return(text_page)


def clean_text(text: str) -> str:
    if not text:
        return ""

    # Unicode-Normalisierung (z.B. zusammengesetzte Zeichen)
    text = unicodedata.normalize("NFC", text)

    # typische OCR-Artefakte entfernen / glätten
    replacements = {
        "¬ ": "",   # Trennfahne
        "- ": "",   # Silbentrennung am Zeilenende
        "= ": "",   # OCR-Fehler
        "^ ": "",   # OCR-Fehler
        " ;": ";",
        " ?": "?",
        "•": "",
    }
    for old, new in replacements.items():
        text = text.replace(old, new)

    # Steuerzeichen entfernen, aber alle Buchstaben/Ziffern/Satzzeichen lassen
    cleaned_chars = []
    for ch in text:
        cat = unicodedata.category(ch)
        # 'C*' = Control, Surrogate, Unassigned, Private use
        if cat.startswith("C"):
            # Standard-Whitespace zu normalem Leerzeichen
            if ch in ("\n", "\r", "\t"):
                cleaned_chars.append(" ")
            # sonst wegwerfen
            continue
        cleaned_chars.append(ch)

    text = "".join(cleaned_chars)

    # Whitespace normalisieren
    text = WHITESPACE_RE.sub(" ", text).strip()

    return text

# %%
# 1 get structure of the current folder
# 2 parse each single file
# 2.1 while parsing, create
start = time.time()
if not os.path.isdir(root+'output/txt/'):
    os.makedirs(root+'output/txt/')
    
processed_journals = [j for j in os.listdir(root+'output/txt/')]


for journal in os.listdir(xml_root):
    
    if journal not in processed_journals:
    
        start_journal = time.time()
        print("Processing", journal, end=" ")
    
        path_struct = os.walk(xml_root+"xml/"+journal)
        for dirpath, dirs, files in path_struct:
            if files != []:
        
                # parse each file
                for file in files:
                    #print(file, end=" ")
                    tree = ET.parse(dirpath+"/"+file)
                    page = xml_to_page(tree)
                    page_text = page_blocks_to_text(page)
                    page_text.replace('"', '‟')
            
                    dirout = root + 'output/txt/' + dirpath.split(xml_root)[1] + '/'
                    fileout = file.split('.')[0] + '.txt'
                    
            
                    if not os.path.exists(dirout):
                        os.makedirs(dirout)
            
                    out = open(dirout+"/"+fileout, "w", encoding="utf-8")
                    out.write(page_text)
                    out.close()
    
        duration_journal = time.time()-start_journal
        print("Done in", round(duration_journal, 2))

print(time.time()-start)         
print("finished")
# Out:
# Processing 2710055 Done in 0.0
# Processing 9616701 Done in 0.0
# Processing 2580773 Done in 0.0
# Processing 2895450 Done in 0.0
# Processing 2727810 Done in 0.0
# Processing 3129675 Done in 0.0
# Processing 6492429 Done in 0.0
# Processing 2438141 Done in 0.0
# Processing 2827798 Done in 0.0
# Processing 5438908 Done in 0.0
# Processing 4782723 Done in 0.0
# Processing 7506414 Done in 0.0
# Processing 9054153 Done in 0.0
# Processing 9366335 Done in 0.0
# Processing 4889892 Done in 0.0
# Processing 2425321 Done in 0.0
# Processing 6492329 Done in 0.0
# Processing 700673 Done in 0.0
# Processing 4895413 Done in 0.0
# Processing 2542917 Done in 0.0
# Processing 9583346 Done in 0.0
# Processing 2549643 Done in 0.0
# Processing 10638461 Done in 0.0
# Processing 3139318 Done in 0.0
# Processing 9620169 Done in 0.0
# Processing 9051331 Done in 0.0
# Processing 4781937 Done in 0.0
# Processing 4911569 Done in 0.0
# Processing 2625941 Done in 0.0
# Processing 2446951 Done in 0.0
# Processing README.md Done in 0.0
# Processing 9643693 Done in 0.0
# Processing 2912821 Done in 0.0
# Processing 6465881 Done in 0.0
# Processing 9643701 Done in 0.0
# Processing 3020846 Done in 0.0
# Processing 9230930 Done in 0.0
# Processing 2644300 Done in 0.0
# Processing 2711613 Done in 0.0
# Processing 6492351 Done in 0.0
# Processing 5367336 Done in 0.0
# Processing 2707513 Done in 0.0
# Processing 2276426 Done in 0.0
# Processing 2360092 Done in 0.0
# Processing 2583479 Done in 0.0
# Processing 9498581 Done in 0.0
# Processing 3101111 Done in 0.0
# Processing 5282534 Done in 0.0
# Processing 2153553 Done in 0.0
# Processing 2577043 Done in 0.0
# Processing 4794838 Done in 0.0
# Processing 4085237 Done in 0.0
# Processing 7938572 Done in 0.0
# Processing 4785731 Done in 0.0
# Processing 4908862 Done in 0.0
# Processing 9768304 Done in 0.0
# Processing 3776398 Done in 0.0
# Processing 4904101 Done in 0.0
# Processing 8798649 Done in 0.0
# Processing 2572068 Done in 0.0
# Processing 2273546 Done in 0.0
# Processing 9620171 Done in 0.0
# Processing 3224737 Done in 0.0
# Processing 3133765 Done in 0.0
# Processing 6467833 Done in 0.0
# Processing 2629891 Done in 0.0
# Processing 9588641 Done in 0.0
# Processing 9643699 Done in 0.0
# Processing 2304627 Done in 0.0
# Processing 9643697 Done in 0.0
# Processing 2621806 Done in 0.0
# Processing 4889559 Done in 0.0
# Processing 8366961 Done in 0.0
# Processing 6485886 Done in 0.0
# Processing 9610648 Done in 0.0
# Processing 9643703 Done in 0.0
# Processing 2638044 Done in 0.0
# Processing 9643691 Done in 0.0
# Processing 4917681 Done in 0.0
# Processing 6492408 Done in 0.0
# Processing 2828641 Done in 0.0
# Processing 9756662 Done in 0.0
# Processing 2650397 Done in 0.0
# Processing 9050316 Done in 0.0
# Processing 1099854 Done in 0.0
# Processing 4883069 Done in 0.0
# Processing 2277379 Done in 0.0
# Processing 9768535 Done in 0.0
# Processing 4869944 Done in 0.0
# Processing 6492308 Done in 0.0
# Processing 6492321 Done in 0.0
# Processing 9582244 Done in 0.0
# Processing 9620166 Done in 0.0
# Processing 8823644 Done in 0.0
# Processing 4789469 Done in 0.0
# Processing 9607226 Done in 0.0
# Processing 9582242 Done in 0.0
# Processing 9539926 Done in 0.0
# Processing 3970005 Done in 0.0
# Processing 2542348 Done in 0.0
# Processing 9610650 Done in 0.0
# Processing 9050333 Done in 0.0
# Processing 2254995 Done in 0.0
# Processing 2431292 Done in 0.0
# Processing 2430890 Done in 0.0
# Processing 2708078 Done in 0.0
# Processing 4920222 Done in 0.0
# Processing 4919024 Done in 0.0
# Processing 2744856 Done in 0.0
# Processing 4885084 Done in 0.0
# Processing 2932754 Done in 0.0
# Processing 9530728 Done in 0.0
# Processing 3126481 Done in 0.0
# Processing 3053752 Done in 0.0
# Processing 10279739 Done in 0.0
# Processing 9643689 Done in 0.0
# Processing 9805360 Done in 0.0
# Processing 3768355 Done in 0.0
# Processing 3497353 Done in 0.0
# Processing 7957787 Done in 0.0
# Processing 3089693 Done in 0.0
# Processing 2379786 Done in 0.0
# Processing 3947615 Done in 0.0
# Processing 7083615 Done in 0.0
# Processing 7691597 Done in 0.0
# Processing 9052070 Done in 0.0
# Processing 2613366 Done in 0.0
# Processing 8620046 Done in 0.0
# Processing 9620164 Done in 0.0
# Processing 3119801 Done in 0.0
# Processing 9047414 Done in 0.0
# Processing 9643687 Done in 0.0
# Processing 3537599 Done in 0.0
# Processing 4874912 Done in 0.0
# Processing 9643695 Done in 0.0
# Processing 6727476 Done in 0.0
# Processing 377570 Done in 0.0
# Processing 4889117 Done in 0.0
# Processing 2437270 Done in 0.0
# Processing 9942709 Done in 0.0
# Processing 9038125 Done in 0.0
# Processing 2045206 Done in 0.0
# Processing 2823768 Done in 0.0
# Processing 9616703 Done in 0.0
# Processing 2583875 Done in 0.0
# Processing 9607695 Done in 0.0
# Processing 6492379 Done in 0.0
# Processing 4086896 Done in 0.0
# Processing 2266000 Done in 0.0
# Processing 2969091 Done in 0.0
# Processing 6492417 Done in 0.0
# Processing 3092672 Done in 0.0
# Processing 2929020 Done in 0.0
# Processing 9230933 Done in 0.0
# Processing 9626633 Done in 0.0
# Processing 7413542 Done in 0.0
# Processing 8861699 Done in 0.0
# Processing 2827066 Done in 0.0
# Processing 7507437 Done in 0.0
# Processing 4911661 Done in 0.0
# Processing 10622931 Done in 0.0
# Processing 1112869 Done in 0.0
# Processing 3769475 Done in 0.0
# Processing 8245601 Done in 0.0
# Processing 2908689 Done in 0.0
# Processing 9556011 Done in 0.0
# Processing 6492437 Done in 0.0
# Processing 3133276 Done in 0.0
# Processing 3315709 Done in 0.0
# Processing 3771019 Done in 0.0
# Processing 9582265 Done in 0.0
# Processing 4890378 Done in 0.0
# Processing 9643678 Done in 0.0
# Processing 3094266 Done in 0.0
# Processing 3504366 Done in 0.0
# Processing 2249537 Done in 0.0
# Processing 4925979 Done in 0.0
# Processing 2268830 Done in 0.0
# Processing 9160972 Done in 0.0
# Processing 7411685 Done in 0.0
# Processing 4903956 Done in 0.0
# Processing 4794429 Done in 0.0
# Processing 4807565 Done in 0.0
# Processing 9610652 Done in 0.0
# Processing 2649276 Done in 0.0
# Processing 6682492 Done in 0.0
# Processing 10112841 Done in 0.0
# Processing 4795427 Done in 0.0
# Processing 9449368 Done in 0.0
# Processing 3476254 Done in 0.0
# Processing 2550626 Done in 0.0
# Processing 4896353 Done in 0.0
# Processing 2641551 Done in 0.0
# Processing 649716 Done in 0.0
# Processing 4899998 Done in 0.0
# Processing 10855476 Done in 0.0
# Processing 3140913 Done in 0.0
# Processing 3983568 Done in 0.0
# Processing 4886575 Done in 0.0
# Processing 4896751 Done in 0.0
# Processing 9934493 Done in 0.0
# Processing 9759310 Done in 0.0
# Processing 7166791 Done in 0.0
# Processing 4916913 Done in 0.0
# Processing 3019627 Done in 0.0
# Processing 2418846 Done in 0.0
# Processing 2822870 Done in 0.0
# Processing 9072829 Done in 0.0
# Processing 6682508 Done in 0.0
# Processing 4872516 Done in 0.0
# Processing 3495278 Done in 0.0
# Processing 2720904 Done in 0.0
# Processing 2825247 Done in 0.0
# Processing 4885029 Done in 0.0
# Processing 8263477 Done in 0.0
# Processing 4903180 Done in 0.0
# Processing 9572329 Done in 0.0
# Processing 2292929 Done in 0.0
# Processing 6492344 Done in 0.0
# Processing 4876568 Done in 0.0
# Processing 2554541 Done in 0.0
# Processing 8823924 Done in 0.0
# Processing 6492456 Done in 0.0
# Processing 4921092 Done in 0.0
# Processing 9160927 Done in 0.0
# Processing 4661555 Done in 0.0
# Processing 9643705 Done in 0.0
# Processing 7086666 Done in 0.0
# Processing 2969669 Done in 0.0
# Processing 10279732 Done in 0.0
# Processing 8495715 Done in 0.0
# Processing 7168181 Done in 0.0
# Processing 2432763 Done in 0.0
# Processing 4884546 Done in 0.0
# Processing 8878932 Done in 0.0
# Processing 4891256 Done in 0.0
# Processing 2417805 Done in 0.0
# Processing 9569929 Done in 0.0
# Processing 7242850 Done in 0.0
# Processing 4864325 Done in 0.0
# Processing 537862 Done in 0.0
# Processing 9626648 Done in 0.0
# Processing 9230935 Done in 0.0
# Processing 6492385 Done in 0.0
# Processing fancyindex.conf Done in 0.0
# Processing 8553624 Done in 0.0
# Processing 2316602 Done in 0.0
# Processing 2692297 Done in 0.0
# Processing 2709933 Done in 0.0
# Processing 2829132 Done in 0.0
# Processing 3062972 Done in 0.0
# Processing 4892693 Done in 0.0
# Processing 9038025 Done in 0.0
# Processing 9805439 Done in 0.0
# Processing 2566634 Done in 0.0
# Processing 2822530 Done in 0.0
# Processing 3135693 Done in 0.0
# Processing 2709108 Done in 0.0
# Processing 2651273 Done in 0.0
# Processing 2566751 Done in 0.0
# Processing 9569290 Done in 0.0
# Processing 2378030 Done in 0.0
# Processing 2429839 Done in 0.0
# Processing 6727475 Done in 0.0
# Processing 3486266 Done in 0.0
# Processing 52596 Done in 0.0
# Processing 3980048 Done in 0.0
# Processing Nginx-Fancyindex-Theme-light Done in 0.0
# Processing 4900572 Done in 0.0
# Processing 2551369 Done in 0.0
# Processing 4861829 Done in 0.0
# Processing 4109741 Done in 0.0
# Processing 2979076 Done in 0.0
# Processing 8295971 Done in 0.0
# Processing 5369809 Done in 0.0
# Processing 9805370 Done in 0.0
# Processing 6492337 Done in 0.0
# Processing 10555104 Done in 0.0
# Processing 2425679 Done in 0.0
# Processing 2254914 Done in 0.0
# Processing 8555529 Done in 0.0
# Processing 177657 Done in 0.0
# Processing 2642950 Done in 0.0
# Processing 6492301 Done in 0.0
# Processing 4884143 Done in 0.0
# Processing 5959619 Done in 0.0
# Processing 2259275 Done in 0.0
# Processing 4908657 Done in 0.0
# Processing 9620162 Done in 0.0
# Processing 9221535 Done in 0.0
# Processing 9643684 Done in 0.0
# Processing 1304829 Done in 0.0
# Processing 9607246 Done in 0.0
# Processing 6492399 Done in 0.0
# Processing 3111067 Done in 0.0
# Processing 2420797 Done in 0.0
# Processing 4804947 Done in 0.0
# Processing 2609281 Done in 0.0
# Processing 3122061 Done in 0.0
# Processing 2424658 Done in 0.0
# Processing 4926451 Done in 0.0
# Processing 2571117 Done in 0.0
# Processing 2708691 Done in 0.0
# Processing 8812431 Done in 0.0
# Processing 9215017 Done in 0.0
# Processing 2420973 Done in 0.0
# Processing 2550047 Done in 0.0
# Processing 4926100 Done in 0.0
# Processing 3138070 Done in 0.0
# Processing 4862473 Done in 0.0
# Processing 8003959 Done in 0.0
# Processing 2821022 Done in 0.0
# Processing 2416673 Done in 0.0
# 0.03395700454711914
