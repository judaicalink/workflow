# %%
import os, pprint, csv, json
import webbrowser as wb
path_data = "/data/cm/output/text/"
path = "/home/rovera/cm/"

# %%
# 3224737_3227986_3228015__49972_3271563

def page_retriever(page_name):
    
    p_path, filename = page_name.split('__')
    p_path = p_path.replace("_", "/")
    filename = filename+".txt"
    
    fullpath = path_data+p_path+"/"+filename
    
    print("http://localhost:18888/edit"+fullpath)

# %%
page = "5369809_5935096_5938085__4615_5376902"
page_retriever(page)
# Out:
# http://localhost:18888/edit/data/cm/output/text/5369809/5935096/5938085/4615_5376902.txt
