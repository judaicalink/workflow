# %%
# build global entity to entity
import os, json, pprint, pickle, os, time
root = "/data/cm/"
root_data = root+"data/"

# %%
sf_to_e = pickle.load(open(root+'data/wiki/de/sf_to_entities.pickle', 'rb'))

# %%
e_to_sfs = pickle.load(open(root+'data/wiki/de/entity_to_sfs.pickle', 'rb'))

# %%
print(len(e_to_sfs))
print(len(sf_to_e))
# Out:
# 5386267
# 7970190

# %%
file = pickle.load(open(root+'output/wiki/entity_to_entity/partials_dict/DP.pickle', 'rb'))

# %%
tot = 0
for v in file.values():
    tot += len(v)

# %%
tot/5300000
# Out:
# 3.709976603773585

# %%
print(file['Madrid'])
# Out:
# {'Aussig': 1, 'Wehrmacht': 1, 'Tschechoslowakei': 3, 'Freier%20Deutscher%20Kulturbund': 1, 'Oskar%20Kokoschka': 1, 'Der%20Tagesspiegel': 1, '%C3%96sterreich-Ungarn': 2, 'Museum%20Folkwang': 1, 'Performance%20%28Kunst%29': 1, 'London': 19, 'Entartete%20Kunst': 1, 'KZ%20Auschwitz': 1, '1968': 2, 'Hampstead%20%28London%29': 1, 'Juden': 1, 'Moskau': 6, 'Berlinische%20Galerie': 1, 'Swansea': 1, 'Einzelausstellung': 1, 'Akademie%20der%20K%C3%BCnste%20%28Berlin%29': 1, 'Geheime%20Staatspolizei': 1, 'J%C3%BCdisches%20Museum%20Berlin': 1, 'Mumbles': 1, 'Kunstforum%20Ostdeutsche%20Galerie': 1, 'Freie%20Secession': 1, 'Edvard%20Bene%C5%A1': 1, 'Juryfreie%20Kunstausstellung': 1, 'Charkiw': 1, '1895': 1, 'Kommunismus': 1, 'Regensburg': 2, 'Frankfurt%20am%20Main': 4, 'Franz%20Thiele': 1, 'J%C3%B3zef%20Mehoffer': 1, 'Akademie%20der%20Bildenden%20K%C3%BCnste%20Krakau': 1, 'New%20York%20City': 5, 'Wintergarten%20%28Variet%C3%A9%29': 1, 'Berliner%20Secession': 1, '11.%20September': 2, 'Krakau': 1, 'Re
# ...
